# %% [markdown]
# # PROJET N° 7 - Implémenter un modèle de scoring
# ## Partie 7 : Annexe 1 - Préparation des jeux de données pour l'entraînement des modèles de classification et pour le tableau de bord Streamlit
# #### Auteur : Henrique DA COSTA
# #### Date : Septembre 2021

# %% [markdown]
# # Plan <a class="anchor" id="plan"></a>
#
# ### [1. Chargement des jeux complets](#1)<a class="anchor" id="plan"></a>
# ### [2. Jeux de données normalisé avec les 50 features principales](#2)<a class="anchor" id="plan"></a>
# ### [3. Jeux de données non normalisé avec les 50 features principales](#3)<a class="anchor" id="plan"></a>
# ### [4. Jeux de données normalisé avec les 350 features principales](#4)<a class="anchor" id="plan"></a>
# ### [5. Jeux de données non normalisé avec les 350 features principales](#5)<a class="anchor" id="plan"></a>
# ### [6. Sauvegardes des différents jeux de données dans le répertoire data_pycaret](#6)<a class="anchor" id="plan"></a>
# ### [7. Préparation des jeux de données pour le tableau de bord (Streamlit)](#7)<a class="anchor" id="plan"></a>
# ### [8. Essais divers](#8)<a class="anchor" id="plan"></a>
# ### [9. Préparation du Logo pour le dashboard](#9)<a class="anchor" id="plan"></a>
#
# ### -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## [1. Chargement des jeux complets](#plan)<a class="anchor" id="1"></a>

# %%
# importation de structures de données 
import pandas as pd
import numpy as np
from scipy.stats import uniform
import matplotlib.pyplot as plt

# %% [markdown]
# **train_df_std et test_df_std normalisés avec identifiant SK_ID_CURR et cible TARGET**

# %%
# Chargement des fichiers pour entraînement pycaret avec identifiant client et target
train_df_std = pd.read_csv('data_pycaret/train_df_std.csv').drop("Unnamed: 0",axis=1)
test_df_std = pd.read_csv('data_pycaret/test_df_std.csv').drop("Unnamed: 0",axis=1)

# %%
display(train_df_std.head(2))
print('shape train_df_std : ', train_df_std.shape)

# %%
display(test_df_std.head(2))
print('shape test_df_std : ', test_df_std.shape)

# %% [markdown]
# **train_df test_df et y non normalisés**

# %%
# Chargement des fichiers csv
train_df = pd.read_csv("data_model/train_data.csv").drop("Unnamed: 0",axis=1) # sans TARGET
test_df = pd.read_csv("data_model/test_data.csv").drop("Unnamed: 0",axis=1) # sans TARGET
y = pd.read_csv("data_model/y_train.csv").drop("Unnamed: 0",axis=1) # TARGET

# %%
# replacing nan values with 0
train_df[np.isnan(train_df)] = 0
test_df[np.isnan(test_df)] = 0
y[np.isnan(y)] = 0

# %%
# display
display(train_df.head(2))
print('shape train_df : ', train_df.shape)

# %%
display(test_df.head(2))
print('shape test_df : ', test_df.shape)

# %%
display(y.head(2))
print('shape y : ', y.shape)

# %% [markdown]
# **train_df test_df et y non normalisés avec avec identifiant SK_ID_CURR et cible TARGET**

# %%
# Chargement des fichiers application_train et application_test
application_train = pd.read_csv('data/application_train.csv')
application_test = pd.read_csv('data/application_test.csv')

# %%
# Ajout de la cible TARGET
train_df['TARGET'] = y['TARGET']

# %%
# Ajout Identifiant client
train_df['SK_ID_CURR'] = application_train['SK_ID_CURR']
test_df['SK_ID_CURR'] = application_test['SK_ID_CURR']

# %%
# Déplacement Identifiant client en première colonne
cols_train = train_df.columns.tolist()
cols_train = cols_train[-1:] + cols_train[:-1]
train_df = train_df[cols_train]

cols_test = test_df.columns.tolist()
cols_test = cols_test[-1:] + cols_test[:-1]
test_df = test_df[cols_test]

# %%
# display
display(train_df.head(2))
print('shape train_df : ', train_df.shape)

# %%
display(test_df.head(2))
print('shape test_df : ', test_df.shape)

# %% [markdown]
# ## [2. Jeux de données normalisé avec les 50 features principales](#plan)<a class="anchor" id="2"></a>

# %%
features_50 = pd.read_csv('data_pycaret/features_50.csv')
var_imp_fin = features_50['Features importance'].values.tolist()
var_imp_fin

# %%
train_df_std_50 = train_df_std[['SK_ID_CURR'] + var_imp_fin + ['TARGET']]
# display
display(train_df_std_50.head(2))
print('shape train_df_std_50 : ', train_df_std_50.shape)

# %%
test_df_std_50 = test_df_std[['SK_ID_CURR'] + var_imp_fin]
# display
display(test_df_std_50.head(2))
print('shape test_df_std_50 : ', test_df_std_50.shape)

# %% [markdown]
# ## [3. Jeux de données non normalisé avec les 50 features principales](#plan)<a class="anchor" id="3"></a>

# %%
train_df_50 = train_df[['SK_ID_CURR'] + var_imp_fin + ['TARGET']]
# display
display(train_df_50.head(2))
print('shape train_df_50 : ', train_df_50.shape)

# %%
test_df_50 = test_df[['SK_ID_CURR'] + var_imp_fin]
# display
display(test_df_50.head(2))
print('shape test_df_50 : ', test_df_50.shape)

# %% [markdown]
# ## [4. Jeux de données normalisé avec les 350 features principales](#plan)<a class="anchor" id="4"></a>

# %%
features_350_lgb = pd.read_csv('data_pycaret/features_350_lgb.csv').drop('Unnamed: 0', axis=1)
var_imp_fin = features_350_lgb['Features importance'].values.tolist()
var_imp_fin
# Out:
# ['TARGET_NEIGHBORS_500_MEAN',
#  'WEEKDAY_APPR_PROCESS_START_1',
#  'REGIONS_RATING_INCOME_MUL_1',
#  'EMERGENCYSTATE_MODE_0',
#  'CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE',
#  'REGION_RATING_CLIENT_0',
#  'FLAG_WORK_PHONE',
#  'CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED',
#  'FLAG_REGIONS',
#  'FLAG_DOCUMENT_3',
#  'CREDIT_EXT_RATIO',
#  'OBS_60_CREDIT_RATIO',
#  'FLAG_CONTACTS_SUM',
#  'WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2',
#  'SK_DPD_DEF_MAX_YEAR_REST_MEAN',
#  'AMT_INCOME_TOTAL_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'WEEKDAY_APPR_PROCESS_START_MAX_ALL',
#  'AMT_CREDIT_SUM_LIMIT_MAX_CREDITACTIVE_ACTIVE',
#  'DAYS_ID_PUBLISH',
#  'FLAG_PHONE',
#  'DAYS_BIRTH',
#  'EXT_SOURCE_MIN',
#  'AMT_PAYMENT_RATIO_MIN_LAST_1_YEAR',
#  'WEIGHTED_EXT_SOURCE',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL',
#  'INSTALLMENTS_ANNUITY_AMT_INSTALMENT_MEAN_MAX_RATIO',
#  'NAME_EDUCATION_TYPE_1',
#  'CREDIT_GOODS_DIFF',
#  'AMT_ANNUITY_CREDIT_RATIO_MEAN_OVERALL',
#  'AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE',
#  'AMT_PAYMENT_DIFF_MAX_LAST_1_YEAR',
#  'CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_CLOSED',
#  'OCCUPATION_TYPE_0',
#  'CAR_EMPLOYED_RATIO',
#  'ORGANIZATION_TYPE_1',
#  'AMT_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS',
#  'NAME_CONTRACT_STATUS_MEAN_ALL',
#  'NAME_TYPE_SUITE_LAST_FIRST_2',
#  'AMT_CREDIT_SUM_SUM_CREDITACTIVE_ACTIVE',
#  'AMT_ANNUITY_SUM_CREDITACTIVE_CLOSED',
#  'EXT_SOURCE_2',
#  'CREDIT_TYPE_Car loan_MEAN_OVERALL',
#  'AMT_ANNUITY',
#  'CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE',
#  'EXT_SOURCE_VAR',
#  'AMT_CREDIT_SUM_DEBT_MEAN_OVERALL',
#  'NAME_YIELD_GROUP_LAST_LAST_5',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'CURRENT_CREDIT_DEBT_DIFF_MIN_CREDITACTIVE_ACTIVE',
#  'DAYS_CREDIT_MAX_CREDITACTIVE_CLOSED',
#  'AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_ACTIVE',
#  'SK_DPD_DEF_MAX_YEAR_1_MEAN',
#  'EXT_SOURCE_3',
#  'INTEREST_SHARE_MAX_ALL',
#  'DEF_30_60_SUM',
#  'DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE',
#  'EXT_SOURCE_MEAN',
#  'DAYS_TERMINATION_MAX_ALL',
#  'EMPLOYED_TO_AGE_RATIO',
#  'AMT_CREDIT_SUM_LIMIT_MEAN_OVERALL',
#  'CURRENT_CREDIT_DEBT_DIFF_MIN_CREDITACTIVE_CLOSED',
#  'DEF_30_CREDIT_RATIO',
#  'CREDIT_GOODS_RATIO',
#  'DAYS_PAYMENT_DIFF_MAX_MEAN',
#  'WEEKDAY_APPR_PROCESS_START_MIN_ALL',
#  'CREDIT_TYPE_Microloan_MEAN_OVERALL',
#  'NAME_CLIENT_TYPE_LAST_FIRST_2',
#  'DAYS_PAYMENT_RATIO_MEAN_MAX',
#  'CREDIT_ANNUITY_RATIO',
#  'AGE_EMPLOYED_DIFF_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'DAYS_CREDIT_MIN_CREDITACTIVE_CLOSED',
#  'NAME_SELLER_INDUSTRY_MEAN_FIRST_2',
#  'REG_REGION_NOT_WORK_REGION',
#  'SK_DPD_DEF_MAX_ACTIVE_MEAN',
#  'CNT_INSTALMENT_MEAN_COMPLETED_SUM',
#  'EXT_SOURCE_3_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'SK_DPD_MAX_YEAR_1_MEAN',
#  'EXP_DAYS_PAYMENT_RATIO_LAST_MEAN',
#  'BUREAU_DAYS_CREDIT_MAX_CREDITACTIVE_CLOSED_EMPLOYED_DIFF',
#  'BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN_OVERALL_INCOME_RATIO',
#  'EXP_AMT_PAYMENT_RATIO_LAST_LAST_1_YEAR',
#  'EXP_CNT_INSTALMENT_FUTURE_LAST_MEAN',
#  'EXT_SOURCE_1_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'DAYS_PAYMENT_DIFF_MIN_FIRST_5_INSTALLMENTS',
#  'DAYS_CREDIT_LAST_CREDITACTIVE_ACTIVE',
#  'MISSING_VALS_TOTAL_APP',
#  'EXP_CNT_INSTALMENT_FUTURE_LAST_ACTIVE_MEAN',
#  'CREDIT_TYPE_Credit card_MEAN_OVERALL',
#  'INTEREST_RATE_MAX_LAST_5',
#  'NAME_CLIENT_TYPE_MEAN_LAST_5',
#  'SELLERPLACE_AREA_MIN_FIRST_2',
#  'DAYS_PAYMENT_DIFF_MIN_MEAN',
#  'EXPECTED_CNT_PAYMENT',
#  'INSTALLMENTS_AMT_PAYMENT_MEAN_MEAN_INCOME_RATIO',
#  'AMT_PAYMENT_DIFF_MEAN_MEAN',
#  'AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL',
#  'AMT_CREDIT_SUM_MAX_CREDITACTIVE_ACTIVE',
#  'NAME_CASH_LOAN_PURPOSE_MEAN_ALL',
#  'EXP_AMT_PAYMENT_DIFF_LAST_MEAN',
#  'EXT_SOURCE_MUL',
#  'ENQ_CREDIT_RATIO',
#  'AMT_GOODS_PRICE',
#  'AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5',
#  'DAYS_EMPLOYED',
#  'EXT_SOURCE_MAX',
#  'WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2',
#  'CURRENT_CREDIT_DEBT_DIFF_MEAN_CREDITACTIVE_CLOSED',
#  'WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2',
#  'SELLERPLACE_AREA_MEAN_FIRST_2',
#  'ANNUITY_INCOME_RATIO_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2',
#  'ANNUITY_INCOME_RATIO_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'AMT_ANNUITY_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'HOUR_APPR_PROCESS_START',
#  'AMT_INSTALMENT_MEAN_LAST_1_YEAR',
#  'HOUR_APPR_PROCESS_START_MAX_LAST_5',
#  'BUREAU_DAYS_CREDIT_MIN_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF',
#  'CNT_NON_CHILDREN',
#  'DAYS_PAYMENT_RATIO_MAX_MEAN',
#  'INSTALLMENTS_AMT_PAYMENT_SUM_SUM_INCOME_RATIO',
#  'EXP_BALANCE_LIMIT_RATIO_LAST',
#  'AGE_EMPLOYED_DIFF_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'CODE_REJECT_REASON_MEAN_ALL',
#  'BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED_EMPLOYED_DIFF',
#  'SK_DPD_RATIO_MEAN_YEAR_1_MEAN',
#  'BUREAU_DAYS_CREDIT_MEAN_OVERALL_EMPLOYED_DIFF',
#  'ANNUITY_INCOME_RATIO',
#  'INTEREST_SHARE_MAX_LAST_5',
#  'AMT_CREDIT_SUM_DEBT_SUM_CREDITACTIVE_ACTIVE',
#  'DAYS_REGISTRATION',
#  'NONLIVINGAPARTMENTS_MEDI',
#  'EXT_SOURCE_1_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'AMT_CREDIT_MAX_OVERDUE_MEAN_OVERALL',
#  'REGION_POPULATION_RELATIVE',
#  'NAME_GOODS_CATEGORY_MEAN_ALL',
#  'HOUR_PROCESS_CREDIT_MUL',
#  'CURRENT_CREDIT_DEBT_DIFF_MEAN_CREDITACTIVE_ACTIVE',
#  'EXP_DAYS_PAYMENT_RATIO_LAST_FIRST_5_INSTALLMENTS',
#  'AMT_ANNUITY_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE',
#  'EXPECTED_INTEREST_SHARE',
#  'DEF_60_CREDIT_RATIO',
#  'DAYS_CREDIT_MAX_CREDITACTIVE_ACTIVE',
#  'EXT_SOURCE_MEAN_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'MONTHS_BALANCE_MEAN_MEAN_OVERALL',
#  'EXP_CNT_INSTALMENT_FUTURE_LAST_COMPLETED_MEAN',
#  'DAYS_PAYMENT_RATIO_MAX_MAX',
#  'MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2',
#  'WEEKDAY_APPR_PROCESS_START_MIN_LAST_5',
#  'DAYS_CREDIT_MIN_CREDITACTIVE_ACTIVE',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'EXT_SOURCE_2_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'AMT_ANNUITY_SUM_CREDITACTIVE_ACTIVE',
#  'EXP_AMT_PAYMENT_RATIO_LAST_MEAN',
#  'EXT_SOURCE_2_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'SK_DPD_SUM_YEAR_1_MEAN',
#  'BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_CLOSED_INCOME_RATIO',
#  'BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF',
#  'HOUSETYPE_MODE_1',
#  'NAME_GOODS_CATEGORY_LAST_FIRST_2',
#  'AMT_ENQ_SUM',
#  'CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_ACTIVE',
#  'AGE_EMPLOYED_DIFF_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'INTEREST_SHARE_MEAN_ALL',
#  'EXT_SOURCE_MEAN_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'EXP_DAYS_PAYMENT_DIFF_LAST_MEAN',
#  'REG_CITY_NOT_LIVE_CITY',
#  'AMT_ANNUITY_CREDIT_RATIO_MIN_CREDITACTIVE_CLOSED',
#  'EXT_SOURCE_1',
#  'WALLSMATERIAL_MODE_0',
#  'AMT_CREDIT_SUM_MEAN_OVERALL',
#  'DAYS_TERMINATION_MAX_LAST_5',
#  'EXT_SOURCE_2_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'AMT_ANNUITY_CREDIT_RATIO_MEAN_CREDITACTIVE_CLOSED',
#  'SK_DPD_RATIO_MAX_MEAN',
#  'CNT_DRAWING_SUM_SUM_YEAR_0',
#  'ANNUITY_MEAN_LAST_5',
#  'CONTRACT_SIGNED_MEAN',
#  'CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_CLOSED',
#  'MIN_PAYMENT_TOTAL_RATIO_MEAN_YEAR_1',
#  'DAYS_DECISION_MEAN_LAST_5',
#  'EXT_SOURCE_1_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE',
#  'EXPECTED_INTEREST_RATE',
#  'DAYS_PAYMENT_RATIO_MAX_FIRST_5_INSTALLMENTS',
#  'GOODS_INCOME_RATIO',
#  'EXP_AMT_PAYMENT_DIFF_LAST_LAST_1_YEAR',
#  'DAYS_CREDIT_LAST_CREDITACTIVE_CLOSED',
#  'RATE_DOWN_PAYMENT_MEAN_ALL',
#  'AMT_INSTALMENT_SUM_MAX',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_DUE_1ST_VERSION_MEAN_LAST_5',
#  'NAME_GOODS_CATEGORY_MEAN_FIRST_2',
#  'PREV_AMT_GOODS_PRICE_SUM_FIRST_2_INCOME_RATIO',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN_INCOME_RATIO',
#  'WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5',
#  'AMT_ANNUITY_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'EXP_POS_TOTAL_TERM_LAST_ACTIVE_MEAN',
#  'EXT_SOURCE_MEAN_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2',
#  'CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL',
#  'DAYS_DETAILS_CHANGE_MUL',
#  'RATE_DOWN_PAYMENT_MEAN_LAST_5',
#  'AMT_CREDIT_LIMIT_ACTUAL_SUM',
#  'CREDIT_TYPE_Consumer credit_MEAN_OVERALL',
#  'CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_MAX',
#  'AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2',
#  'DAYS_PAYMENT_DIFF_MAX_MAX',
#  'LANDAREA_MODE',
#  'AMT_CREDIT_SUM_MAX_CREDITACTIVE_CLOSED',
#  'INSTALLMENTS_AMT_PAYMENT_MAX_MEAN_INCOME_RATIO',
#  'SK_DPD_RATIO_MEAN_YEAR_0_SUM',
#  'CNT_INSTALMENT_FUTURE_MIN_MEAN',
#  'BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_ACTIVE_INCOME_RATIO',
#  'DAYS_LAST_DUE_1ST_VERSION_MEAN_ALL',
#  'CNT_INSTALMENT_FUTURE_MIN_YEAR_REST_MEAN',
#  'EXT_SOURCE_3_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'INSTALLMENTS_AMT_PAYMENT_MEAN_LAST_1_YEAR_INCOME_RATIO',
#  'DAYS_FIRST_DRAWING_MEAN_FIRST_2',
#  'COMMONAREA_MODE',
#  'EXT_SOURCE_3_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE',
#  'AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2',
#  'AMT_PAYMENT_MAX_LAST_1_YEAR',
#  'APARTMENTS_SUM_MEDI',
#  'AMT_CREDIT_GOODS_DIFF_SUM_ALL',
#  'AMT_DRAWINGS_CURRENT_MAX',
#  'CNT_INSTALMENT_FUTURE_MEAN_ACTIVE_MEAN',
#  'AMT_ANNUITY_MEAN_ALL',
#  'ANNUITY_INCOME_RATIO_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'SELLERPLACE_AREA_MEAN_ALL',
#  'EXT_SOURCE_MEAN_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'EXT_SOURCE_3_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'EXP_POS_TOTAL_TERM_LAST_YEAR_0_MEAN',
#  'AGE_EMPLOYED_DIFF_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'CNT_INSTALMENT_FUTURE_MEAN_SUM',
#  'SELLERPLACE_AREA_MAX_FIRST_2',
#  'AMT_INTEREST_SUM_ALL',
#  'CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_CLOSED',
#  'NAME_SELLER_INDUSTRY_LAST_FIRST_2',
#  'BASEMENTAREA_MODE',
#  'INCOME_ANNUITY_DIFF',
#  'FLOORSMIN_AVG',
#  'AMT_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS',
#  'AMT_PAYMENT_DIFF_MEAN_MIN',
#  'AMT_CREDIT_SUM_SUM_CREDITACTIVE_CLOSED',
#  'AMT_INSTALMENT_MAX_MEAN',
#  'DAYS_FIRST_LAST_DUE_DIFF_MEAN_FIRST_2',
#  'EXT_SOURCE_3_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'CONTRACT_COMPLETED_MEAN',
#  'CNT_INSTALMENT_FUTURE_MEAN_YEAR_1_SUM',
#  'PREV_AMT_ANNUITY_MEAN_ALL_INCOME_RATIO',
#  'CAR_AGE_DIFF',
#  'ANNUITY_INCOME_RATIO_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'INSTALLMENTS_AMT_PAYMENT_MAX_LAST_1_YEAR_INCOME_RATIO',
#  'NUM_INSTALMENT_VERSION_SUM_FIRST_5_INSTALLMENTS',
#  'ANNUITY_INCOME_RATIO_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'DAYS_FIRST_DUE_MEAN_FIRST_2',
#  'NUM_INSTALMENT_VERSION_SUM_MEAN',
#  'DAYS_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS',
#  'BUREAU_DAYS_CREDIT_LAST_CREDITACTIVE_CLOSED_REGISTRATION_DIFF',
#  'EXT_SOURCE_MEAN_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'AMT_DECLINED_SUM_FIRST_2',
#  'DAYS_DECISION_MIN_LAST_5',
#  'AMT_ANNUITY_MAX_FIRST_2',
#  'EXPECTED_INTEREST',
#  'BUREAU_AMT_CREDIT_SUM_OVERDUE_SUM_CREDITACTIVE_ACTIVE_INCOME_RATIO',
#  'BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE_INCOME_RATIO',
#  'FONDKAPREMONT_MODE_0',
#  'EXP_PAYMENT_MIN_DIFF_LAST',
#  'NAME_CLIENT_TYPE_MEAN_FIRST_2',
#  'AMT_REQ_CREDIT_BUREAU_DAY',
#  'WEIGHTED_STATUS_MEAN_MEAN_CREDITACTIVE_CLOSED',
#  'NAME_CASH_LOAN_PURPOSE_LAST_LAST_5',
#  'AMT_ANNUITY_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE',
#  'APARTMENTS_SUM_AVG_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'DAYS_DETAILS_CHANGE_SUM',
#  'RATE_DOWN_PAYMENT_MAX_ALL',
#  'DAYS_PAYMENT_RATIO_MIN_MIN',
#  'ELEVATORS_AVG',
#  'EXP_DAYS_PAYMENT_RATIO_LAST_LAST_1_YEAR',
#  'AMT_INCOME_TOTAL_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'CONTRACT_ACTIVE_MEAN',
#  'AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2',
#  'AMT_CREDIT_GOODS_DIFF_MIN_FIRST_2',
#  'APARTMENTS_SUM_MEDI_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'INTEREST_RATE_MEAN_LAST_5',
#  'AMT_INCOME_TOTAL_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'DAYS_DECISION_MEAN_FIRST_2',
#  'WEEKDAY_APPR_PROCESS_START_MEAN_ALL',
#  'ANNUITY_INCOME_RATIO_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'DAYS_FIRST_DRAWING_MAX_LAST_5',
#  'AGE_EMPLOYED_DIFF_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY',
#  'AMT_CREDIT_GOODS_DIFF_MAX_LAST_5',
#  'AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2',
#  'NAME_TYPE_SUITE_0',
#  'AMT_APPLICATION_SUM_ALL',
#  'EXP_SK_DPD_RATIO_LAST_YEAR_1',
#  'AMT_INTEREST_MIN_LAST_5',
#  'EXT_SOURCE_2_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'NAME_FAMILY_STATUS_0',
#  'DAYS_PAYMENT_RATIO_MAX_LAST_1_YEAR',
#  'EXT_SOURCE_2_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'ANNUITY_INCOME_RATIO_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE',
#  'CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_SUM',
#  'WEIGHTED_STATUS_SUM_MEAN_OVERALL',
#  'ANNUITY_INCOME_RATIO_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'CC_EXP_AMT_RECEIVABLE_PRINCIPAL_LAST_INCOME_RATIO',
#  'TOTAL_TERM_MEAN_YEAR_0_SUM',
#  'DAYS_FIRST_DUE_MAX_FIRST_2',
#  'PAYMENT_MIN_DIFF_MIN_YEAR_0',
#  'EXT_SOURCE_MEAN_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'DAYS_FIRST_LAST_DUE_DIFF_MAX_LAST_5',
#  'AGE_EMPLOYED_DIFF_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE',
#  'NAME_PORTFOLIO_MEAN_LAST_5',
#  'DAYS_FIRST_LAST_DUE_DIFF_MAX_ALL',
#  'CNT_INSTALMENT_FUTURE_MAX_MEAN',
#  'SELLERPLACE_AREA_MAX_LAST_5',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'NAME_GOODS_CATEGORY_LAST_LAST_5',
#  'EXT_SOURCE_1_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE',
#  'INSTALLMENTS_AMT_PAYMENT_SUM_LAST_1_YEAR_INCOME_RATIO',
#  'ANNUITY_GOODS_MEAN_FIRST_2',
#  'EXP_ENCODED_STATUS_LAST_YEAR_1_MEAN_OVERALL',
#  'APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2',
#  'MIN_PAYMENT_RATIO_MEAN_YEAR_0',
#  'AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL',
#  'DAYS_DECISION_MAX_LAST_5',
#  'NAME_CONTRACT_TYPE_MEAN_ALL',
#  'AMT_PAYMENT_DIFF_MEAN_MAX',
#  'AMT_REQ_CREDIT_BUREAU_WEEK',
#  'AMT_DOWN_PAYMENT_MEAN_LAST_5',
#  'AMT_CREDIT_SUM_LIMIT_SUM_CREDITACTIVE_ACTIVE',
#  'NUM_INSTALMENT_VERSION_SUM_LAST_1_YEAR',
#  'AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5',
#  'AMT_ANNUITY_MEAN_CREDITACTIVE_CLOSED',
#  'AMT_PAYMENT_DIFF_MAX_MAX',
#  'CREDIT_ACTIVE_Bad debt_MEAN_OVERALL',
#  'NUM_INSTALMENT_NUMBER_MAX_MEAN',
#  'WEIGHTED_STATUS_FIRST_MEAN_OVERALL',
#  'DAYS_FIRST_DUE_MAX_ALL',
#  'DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS',
#  'INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO',
#  'AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL',
#  'CHANNEL_TYPE_MEAN_LAST_5',
#  'DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR',
#  'INTEREST_SHARE_MIN_ALL',
#  'NAME_PAYMENT_TYPE_MEAN_LAST_5',
#  'MISSING_VALS_TOTAL_INSTAL_SUM_SUM',
#  'CHILDREN_INCOME_RATIO']

# %%
train_df_std_350 = train_df_std[['SK_ID_CURR'] + var_imp_fin + ['TARGET']]
# display
display(train_df_std_350.head(2))
print('shape train_df_std_350 : ', train_df_std_350.shape)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100002                   3.190860                      0.449980
# 1      100003                  -0.567492                     -1.632332
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                     0.384462               0.963572
# 1                    -0.025011               0.963572
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                          -0.020491
# 1                                          -0.020491
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                0.113357        -0.498997
# 1                2.030894        -0.498997
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                          -0.023502         -0.548348  ...
# 1                                          -0.023502         -0.548348  ...
#
#    DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS  \
# 0                                     0.075480
# 1                                     0.613073
#
#    INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO  \
# 0                                      -0.468936
# 1                                       0.515149
#
#    AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL  CHANNEL_TYPE_MEAN_LAST_5  \
# 0                              -0.542670                 -0.420433
# 1                               0.404742                 -0.420433
#
#    DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR  INTEREST_SHARE_MIN_ALL  \
# 0                           0.091097                0.784658
# 1                           0.000000                0.559187
#
#    NAME_PAYMENT_TYPE_MEAN_LAST_5  MISSING_VALS_TOTAL_INSTAL_SUM_SUM  \
# 0                       1.843181                          -0.032451
# 1                      -0.076989                          -0.032451
#
#    CHILDREN_INCOME_RATIO  TARGET
# 0              -0.491786       1
# 1              -0.491786       0
#
# [2 rows x 352 columns]
# shape train_df_std_350 :  (307507, 352)

# %%
test_df_std_350 = test_df_std[['SK_ID_CURR'] + var_imp_fin]
# display
display(test_df_std_350.head(2))
print('shape test_df_std_350 : ', test_df_std_350.shape)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100001                  -0.285805                      1.362144
# 1      100005                   0.494892                      0.343595
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                    -0.069788               0.928229
# 1                     0.267753              -1.073187
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                          -0.032632
# 1                                          -0.032632
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                0.083711        -0.507337
# 1                0.083711        -0.507337
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0         -0.537128  ...
# 1                                                0.0         -0.537128  ...
#
#    DAYS_FIRST_DUE_MAX_ALL  DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS  \
# 0               -1.967520                                     0.611481
# 1               -0.167845                                    -0.060647
#
#    INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO  \
# 0                                      -0.730938
# 1                                      -0.630161
#
#    AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL  CHANNEL_TYPE_MEAN_LAST_5  \
# 0                              -0.644754                 -1.451316
# 1                              -0.638017                 -0.468492
#
#    DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR  INTEREST_SHARE_MIN_ALL  \
# 0                                0.0                1.016121
# 1                                0.0                1.203510
#
#    NAME_PAYMENT_TYPE_MEAN_LAST_5  MISSING_VALS_TOTAL_INSTAL_SUM_SUM  \
# 0                      -1.159899                          -0.044103
# 1                       0.291131                          -0.044103
#
#    CHILDREN_INCOME_RATIO
# 0               -0.48983
# 1               -0.48983
#
# [2 rows x 351 columns]
# shape test_df_std_350 :  (48744, 351)

# %% [markdown]
# ## [5. Jeux de données non normalisé avec les 350 features principales](#plan)<a class="anchor" id="5"></a>

# %%
train_df_350 = train_df[['SK_ID_CURR'] + var_imp_fin + ['TARGET']]
# display
display(train_df_350.head(2))
print('shape train_df_350 : ', train_df_350.shape)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100002                       0.29                        0.0816
# 1      100003                       0.04                        0.0776
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                      0.09045                   0.93
# 1                      0.08010                   0.93
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                            0.27309
# 1                                            0.00000
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                  0.9210                0
# 1                  0.9517                0
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0                 0  ...
# 1                                                0.0                 0  ...
#
#    DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS  \
# 0                                       0.9507
# 1                                       0.9893
#
#    INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO  \
# 0                                       1.084571
# 1                                       4.262879
#
#    AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL  CHANNEL_TYPE_MEAN_LAST_5  \
# 0                              1611495.0                       2.0
# 1                             19378224.0                       2.0
#
#    DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR  INTEREST_SHARE_MIN_ALL  \
# 0                               24.0                  0.2401
# 1                                0.0                  0.1112
#
#    NAME_PAYMENT_TYPE_MEAN_LAST_5  MISSING_VALS_TOTAL_INSTAL_SUM_SUM  \
# 0                          2.000                                0.0
# 1                          1.333                                0.0
#
#    CHILDREN_INCOME_RATIO  TARGET
# 0                    0.0       1
# 1                    0.0       0
#
# [2 rows x 352 columns]
# shape train_df_350 :  (307507, 352)

# %%
test_df_350 = test_df[['SK_ID_CURR'] + var_imp_fin]
# display
display(test_df_350.head(2))
print('shape test_df_350 : ', test_df_350.shape)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100001                      0.064                        0.0835
# 1      100005                      0.114                        0.0815
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                       0.0801                  0.930
# 1                       0.0858                  0.907
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                           0.659208
# 1                                           0.901884
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                   0.921                0
# 1                   0.921                0
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0                 0  ...
# 1                                                0.0                 0  ...
#
#    DAYS_FIRST_DUE_MAX_ALL  DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS  \
# 0                 -1709.0                                       0.9897
# 1                  -706.0                                       0.9460
#
#    INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO  \
# 0                                       0.216673
# 1                                       0.567291
#
#    AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL  CHANNEL_TYPE_MEAN_LAST_5  \
# 0                               309231.0                       1.0
# 1                               441688.5                       2.0
#
#    DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR  INTEREST_SHARE_MIN_ALL  \
# 0                                0.0                  0.3289
# 1                                0.0                  0.4385
#
#    NAME_PAYMENT_TYPE_MEAN_LAST_5  MISSING_VALS_TOTAL_INSTAL_SUM_SUM  \
# 0                            1.0                                0.0
# 1                            1.5                                0.0
#
#    CHILDREN_INCOME_RATIO
# 0                    0.0
# 1                    0.0
#
# [2 rows x 351 columns]
# shape test_df_350 :  (48744, 351)

# %% [markdown]
# ## [6. Sauvegardes des différents jeux de données dans le répertoire data_pycaret](#plan)<a class="anchor" id="6"></a>

# %%
train_df.to_csv('data_pycaret/train_df.csv')
test_df.to_csv('data_pycaret/test_df.csv')
train_df_50.to_csv('data_pycaret/train_df_50.csv')
test_df_50.to_csv('data_pycaret/test_df_50.csv')
train_df_std_50.to_csv('data_pycaret/train_df_std_50.csv')
test_df_std_50.to_csv('data_pycaret/test_df_std_50.csv')

# %%
train_df_std_350.to_csv('data_pycaret/train_df_std_350.csv')
test_df_std_350.to_csv('data_pycaret/test_df_std_350.csv')
train_df_350.to_csv('data_pycaret/train_df_350.csv')
test_df_350.to_csv('data_pycaret/test_df_350.csv')

# %% [markdown]
# ## [7. Préparation des jeux de données pour le tableau de bord (Streamlit)](#plan)<a class="anchor" id="7"></a>

# %% [markdown]
# ### **Prédictions pycaret**

# %%
test_predict_pycaret  = pd.read_csv('data_pycaret/test_df_std_50.csv').drop('Unnamed: 0',axis=1).sample(n=10000)
test_predict_pycaret.to_csv('data_tableau/test_predict_pycaret.csv')
test_predict_pycaret.head()
# Out:
#        SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 41206      402772                  -0.160894                      0.394523
# 37546      374796                  -0.317033                     -1.642575
# 15066      208482                  -0.660540                      0.394523
# 24545      278932                   1.369273                      1.362144
# 39974      394336                  -0.754224                      0.394523
#
#        REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 41206                     0.380267               0.928229
# 37546                     0.023184               0.928229
# 15066                    -1.301518               0.928229
# 24545                    -0.069788              -1.073187
# 39974                    -0.573139              -1.073187
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 41206                                          -0.032632
# 37546                                          -0.032632
# 15066                                          -0.032632
# 24545                                           0.000000
# 39974                                           0.000000
#
#        REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 41206                0.083711        -0.507337
# 37546                0.083711        -0.507337
# 15066                1.953014         1.971078
# 24545                0.083711        -0.507337
# 39974                0.083711        -0.507337
#
#        CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  \
# 41206                                          -0.018016          1.276328
# 37546                                           0.000000         -0.537128
# 15066                                           0.000000          3.089785
# 24545                                          -0.018016          1.276328
# 39974                                           0.000000         -0.537128
#
#        ...  AMT_ANNUITY_SUM_CREDITACTIVE_CLOSED  EXT_SOURCE_2  \
# 41206  ...                            -0.030868      0.717074
# 37546  ...                            -0.030868      0.404278
# 15066  ...                            -0.030868     -0.627344
# 24545  ...                            -0.030868     -1.279969
# 39974  ...                             0.000000      0.493096
#
#        CREDIT_TYPE_Car loan_MEAN_OVERALL  AMT_ANNUITY  \
# 41206                          -0.211078    -0.302365
# 37546                          -0.211078    -0.467573
# 15066                          -0.211078     1.649502
# 24545                          -0.211078     2.334215
# 39974                           0.000000    -1.119975
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  EXT_SOURCE_VAR  \
# 41206                                          -0.008465           0.906861
# 37546                                          -0.008465           1.898589
# 15066                                          -0.008465          -0.386347
# 24545                                           0.000000          -0.506860
# 39974                                           0.000000          -0.778057
#
#        AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  NAME_YIELD_GROUP_LAST_LAST_5  \
# 41206                         -0.284322                     -0.945917
# 37546                          0.300819                     -0.945917
# 15066                         -0.284322                      1.015738
# 24545                         -0.284322                      1.015738
# 39974                          0.000000                     -0.945917
#
#        LIVE_CITY_NOT_WORK_CITY  \
# 41206                 2.177152
# 37546                -0.459316
# 15066                 2.177152
# 24545                 2.177152
# 39974                -0.459316
#
#        ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY
# 41206                                          -1.637561
# 37546                                          -0.791311
# 15066                                           1.243109
# 24545                                           0.567819
# 39974                                           0.490887
#
# [5 rows x 51 columns]

# %%
test_predict_pycaret.shape
# Out:
# (10000, 51)

# %% [markdown]
# ### **Informations client sélectionné**

# %%
test_df_50 = pd.read_csv('data_pycaret/test_df_50.csv').drop('Unnamed: 0',axis=1)

# %%
test_df =  pd.read_csv('data_pycaret/test_df.csv').drop('Unnamed: 0',axis=1)
test_info_client = test_df_50

# %%
test_info_client[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']] = \
    test_df[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']]

# %%
application_test=pd.read_csv('data/application_test.csv')
test_info_client[['CODE_GENDER', 'NAME_FAMILY_STATUS', 'NAME_CONTRACT_TYPE']] = application_test[['CODE_GENDER', 'NAME_FAMILY_STATUS', 'NAME_CONTRACT_TYPE']]
display(test_info_client.head())
print(test_info_client.shape)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100001                      0.064                        0.0835
# 1      100005                      0.114                        0.0815
# 2      100013                      0.008                        0.0776
# 3      100028                      0.026                        0.0816
# 4      100038                      0.122                        0.0815
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                      0.08010                  0.930
# 1                      0.08580                  0.907
# 2                      0.09045                  0.907
# 3                      0.06604                  0.930
# 4                      0.08167                  0.907
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                           0.659208
# 1                                           0.901884
# 2                                           0.000000
# 3                                           0.275100
# 4                                           0.000000
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                   0.921                0
# 1                   0.921                0
# 2                   0.921                0
# 3                   0.921                0
# 4                   0.921                1
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0                 0  ...
# 1                                                0.0                 0  ...
# 2                                                0.0                 0  ...
# 3                                                0.0                 0  ...
# 4                                                0.0                 2  ...
#
#    NAME_YIELD_GROUP_LAST_LAST_5  LIVE_CITY_NOT_WORK_CITY  \
# 0                           4.0                        0
# 1                           0.0                        0
# 2                           0.0                        0
# 3                           0.0                        0
# 4                           3.0                        1
#
#    ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                             0.1870
# 1                                             0.1686
# 2                                             0.1621
# 3                                             0.1870
# 4                                             0.1621
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE  CODE_GENDER  \
# 0          135000.0    568800.0             0         450000.0            F
# 1           99000.0    222768.0             0         180000.0            M
# 2          202500.0    663264.0             0         630000.0            M
# 3          315000.0   1575000.0             2        1575000.0            F
# 4          180000.0    625500.0             1         625500.0            M
#
#    NAME_FAMILY_STATUS  NAME_CONTRACT_TYPE
# 0             Married          Cash loans
# 1             Married          Cash loans
# 2             Married          Cash loans
# 3             Married          Cash loans
# 4             Married          Cash loans
#
# [5 rows x 58 columns]
# (48744, 58)

# %%
test_info_client.to_csv('data_tableau/test_info_client.csv')

# %% [markdown]
# ### **Jeux de données SHAP_Values**

# %%
train_df_std_50 =pd.read_csv('data_pycaret/train_df_std_50.csv').drop('Unnamed: 0', axis=1)
test_df_std_50 = pd.read_csv('data_pycaret/test_df_std_50.csv').drop('Unnamed: 0', axis=1)
y_train = pd.read_csv('data_pycaret/y_train.csv').drop('Unnamed: 0', axis=1)

print('train : ', train_df_std_50.shape)
print('test : ', test_df_std_50.shape)
print('y : ', y_train.shape)
# Out:
# train :  (307507, 52)
# test :  (48744, 51)
# y :  (307507, 1)

# %%
train_df_std = pd.read_csv('data_pycaret/train_df_std.csv').drop('Unnamed: 0', axis=1)
train_df_std.head(2)
# Out:
#    SK_ID_CURR  AMT_PAYMENT_RATIO_MAX_LAST_1_YEAR  \
# 0      100002                          -0.009648
# 1      100003                           0.000000
#
#    EXP_AMT_PAYMENT_RATIO_LAST_MEAN  AMT_DECLINED_SUM_FIRST_2  \
# 0                        -0.002416                  0.271139
# 1                        -0.002416                  0.129771
#
#    CNT_INSTALMENT_MEAN_REST_MAX  HOUSETYPE_MODE_0  \
# 0                           0.0          1.018575
# 1                           0.0          1.018575
#
#    MISSING_VALS_TOTAL_INSTAL_SUM_SUM  CONTRACT_APPROVED_MEAN  \
# 0                          -0.032451               -0.075677
# 1                          -0.032451               -0.075677
#
#    EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_1  \
# 0                                  0.0
# 1                                  0.0
#
#    APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL  ...  \
# 0                                   -0.095605  ...
# 1                                   -0.041137  ...
#
#    APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE  \
# 0                                           0.017702
# 1                                           0.466200
#
#    SELLERPLACE_AREA_MIN_FIRST_2  ANNUITY_SUM_FIRST_2  AMT_DECLINED_SUM_ALL  \
# 0                      0.192722            -0.252734              0.454473
# 1                     -0.026475            -0.252727             -0.193827
#
#    CNT_INSTALMENT_MAX_YEAR_1_MEAN  AMT_ANNUITY_MEAN_CREDITACTIVE_CLOSED  \
# 0                        0.496989                             -0.058948
# 1                       -0.803373                              0.000000
#
#    DAYS_FIRST_LAST_DUE_DIFF_MEAN_ALL  STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE  \
# 0                           1.688603                              0.644405
# 1                          -0.286960                              0.000000
#
#    ANNUITY_GOODS_MEAN_FIRST_2  TARGET
# 0                   -0.146353       1
# 1                   -0.146346       0
#
# [2 rows x 1243 columns]

# %%
train_df_std.shape

# %%
test_df_std = pd.read_csv('data_pycaret/test_df_std.csv').drop('Unnamed: 0', axis=1)
test_df_std.head(2)
# Out:
#    SK_ID_CURR  AMT_PAYMENT_RATIO_MAX_LAST_1_YEAR  \
# 0      100001                                0.0
# 1      100005                                0.0
#
#    EXP_AMT_PAYMENT_RATIO_LAST_MEAN  AMT_DECLINED_SUM_FIRST_2  \
# 0                        -0.004855                  0.275682
# 1                        -0.004855                  0.323084
#
#    CNT_INSTALMENT_MEAN_REST_MAX  HOUSETYPE_MODE_0  \
# 0                           0.0          0.985322
# 1                           0.0         -1.003499
#
#    MISSING_VALS_TOTAL_INSTAL_SUM_SUM  CONTRACT_APPROVED_MEAN  \
# 0                          -0.044103               -0.076727
# 1                          -0.044103               -0.076727
#
#    EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_1  \
# 0                                  0.0
# 1                                  0.0
#
#    APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL  ...  \
# 0                                   -0.127721  ...
# 1                                   -0.124166  ...
#
#    AMT_INCOME_TOTAL_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                          -0.783238
# 1                                           0.253911
#
#    APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE  \
# 0                                          -0.755249
# 1                                          -0.301066
#
#    SELLERPLACE_AREA_MIN_FIRST_2  ANNUITY_SUM_FIRST_2  AMT_DECLINED_SUM_ALL  \
# 0                     -0.102941            -0.249206              0.458227
# 1                     -0.113035            -0.249206              0.472952
#
#    CNT_INSTALMENT_MAX_YEAR_1_MEAN  AMT_ANNUITY_MEAN_CREDITACTIVE_CLOSED  \
# 0                        0.000000                             -0.059158
# 1                       -0.549125                             -0.059158
#
#    DAYS_FIRST_LAST_DUE_DIFF_MEAN_ALL  STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE  \
# 0                          -1.089177                             -0.241684
# 1                          -0.138740                             -0.644074
#
#    ANNUITY_GOODS_MEAN_FIRST_2
# 0                   -0.170972
# 1                   -0.170972
#
# [2 rows x 1242 columns]

# %%
test_df_std.shape
# Out:
# (48744, 1242)

# %%
train_shap = train_df_std_50
train_shap[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']] = train_df_std[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']]
train_sample = train_shap.sample(n=10000)
y_train = train_sample['TARGET']
train_shap = train_sample.drop(['TARGET_NEIGHBORS_500_MEAN', 'TARGET'], axis=1)
train_shap.shape
# Out:
# (10000, 54)

# %%
test_shap = test_df_std_50
test_shap[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']] = test_df_std[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']]
test_sample = test_shap
test_shap = test_sample.drop(['TARGET_NEIGHBORS_500_MEAN'], axis=1)
test_shap.shape
# Out:
# (48744, 54)

# %%
y_shap = y_train
y_shap.shape
# Out:
# (10000,)

# %%
display(train_shap.head(2))
print(train_shap.shape)
display(test_shap.head(2))
print(test_shap.shape)
display(y_shap.head(2))
print(y_shap.shape)

# %%
# Sauvegardes
train_shap.to_csv('data_tableau/train_shap.csv')
test_shap.to_csv('data_tableau/test_shap.csv')
y_shap.to_csv('data_tableau/y_shap.csv')

# %% [markdown]
# ### **Jeux de données pour comparaison**

# %%
train_df_50 = pd.read_csv('data_pycaret/train_df_50.csv').drop('Unnamed: 0',axis=1)
train_df_50.head(2)
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100002                       0.29                        0.0816
# 1      100003                       0.04                        0.0776
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                      0.09045                   0.93
# 1                      0.08010                   0.93
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                            0.27309
# 1                                            0.00000
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                  0.9210                0
# 1                  0.9517                0
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0                 0  ...
# 1                                                0.0                 0  ...
#
#    EXT_SOURCE_2  CREDIT_TYPE_Car loan_MEAN_OVERALL  AMT_ANNUITY  \
# 0         0.263                                0.0      24700.5
# 1         0.622                                0.0      35698.5
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  EXT_SOURCE_VAR  \
# 0                                                0.0           0.005646
# 1                                                0.0           0.016340
#
#    AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  NAME_YIELD_GROUP_LAST_LAST_5  \
# 0                           49156.2                           2.0
# 1                               0.0                           2.0
#
#    LIVE_CITY_NOT_WORK_CITY  \
# 0                        0
# 1                        0
#
#    ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                             0.1686
# 1                                             0.1958
#
#    TARGET
# 0       1
# 1       0
#
# [2 rows x 52 columns]

# %%
train_df =  pd.read_csv('data_pycaret/train_df.csv').drop('Unnamed: 0',axis=1)
train_compare = train_df_50

# %%
train_compare[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']] = \
    train_df[['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'CNT_CHILDREN', 'AMT_GOODS_PRICE']]

# %%
application_train=pd.read_csv('data/application_train.csv')
train_compare[['CODE_GENDER', 'NAME_FAMILY_STATUS', 'NAME_CONTRACT_TYPE']] = application_train[['CODE_GENDER', 'NAME_FAMILY_STATUS', 'NAME_CONTRACT_TYPE']]
train_compare.head()
# Out:
#    SK_ID_CURR  TARGET_NEIGHBORS_500_MEAN  WEEKDAY_APPR_PROCESS_START_1  \
# 0      100002                      0.290                        0.0816
# 1      100003                      0.040                        0.0776
# 2      100004                      0.016                        0.0776
# 3      100006                      0.032                        0.0816
# 4      100007                      0.056                        0.0810
#
#    REGIONS_RATING_INCOME_MUL_1  EMERGENCYSTATE_MODE_0  \
# 0                      0.09045                  0.930
# 1                      0.08010                  0.930
# 2                      0.07160                  0.907
# 3                      0.08010                  0.907
# 4                      0.09690                  0.907
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                            0.27309
# 1                                            0.00000
# 2                                            0.00000
# 3                                            0.00000
# 4                                            0.00000
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                  0.9210                0
# 1                  0.9517                0
# 2                  0.9210                1
# 3                  0.9210                0
# 4                  0.9210                0
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  ...  \
# 0                                                0.0                 0  ...
# 1                                                0.0                 0  ...
# 2                                                0.0                 0  ...
# 3                                                0.0                 0  ...
# 4                                                0.0                 2  ...
#
#    LIVE_CITY_NOT_WORK_CITY  \
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        1
#
#    ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                             0.1686
# 1                                             0.1958
# 2                                             0.1621
# 3                                             0.1870
# 4                                             0.1686
#
#    TARGET  AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE  \
# 0       1          202500.0    406597.5             0         351000.0
# 1       0          270000.0   1293502.5             0        1129500.0
# 2       0           67500.0    135000.0             0         135000.0
# 3       0          135000.0    312682.5             0         297000.0
# 4       0          121500.0    513000.0             0         513000.0
#
#    CODE_GENDER    NAME_FAMILY_STATUS  NAME_CONTRACT_TYPE
# 0            M  Single / not married          Cash loans
# 1            F               Married          Cash loans
# 2            M  Single / not married     Revolving loans
# 3            F        Civil marriage          Cash loans
# 4            M  Single / not married          Cash loans
#
# [5 rows x 59 columns]

# %%
train_compare = train_compare.sample(n=10000)
train_compare.shape
# Out:
# (10000, 59)

# %%
train_compare.to_csv('data_tableau/train_compare.csv')

# %% [markdown]
# ## [8. Essais divers](#plan)<a class="anchor" id="8"></a>

# %% [markdown]
# ### **Prédictions sur le unseen**

# %%
test_df_std_50 = pd.read_csv('data_pycaret/test_df_std_50.csv').drop('Unnamed: 0', axis=1)
test_df_std_50.head()

# %%
unseen_predictions_lightgbm = pd.read_csv('results_model_lighgbm/unseen_predictions_lightgbm.csv')
unseen_predictions_lightgbm.head()

# %%
unseen_predictions_lightgbm.TARGET.values

# %%
int(unseen_predictions_lightgbm[unseen_predictions_lightgbm['SK_ID_CURR'] == 100005].Score.values)

# %%
# Librairie Pycaret
import pycaret
from pycaret.classification import *
from pycaret.utils import check_metric
from sklearn.metrics import log_loss
from pycaret.classification import load_model, predict_model

LGBMClassifier  =  load_model ( 'Save_Model/Final LightGbm Model 23sept2021' )

unseen_essai_lr  =  predict_model ( LGBMClassifier ,  data = train_compare )

# %%
unseen_essai_lr.head()

# %%
unseen_essai_lr.Label.value_counts()

# %% [markdown]
# **SHAP VALUES - FEATURES IMPORTANCES - LightGbm**

# %% [markdown]
# **Smote target**

# %%
# check version number
import imblearn
print(imblearn.__version__)
# Out:
# 0.7.0

# %%
from imblearn.over_sampling import SMOTE

# %%
X = train_shap
X.head(2)
# Out:
#         SK_ID_CURR  WEEKDAY_APPR_PROCESS_START_1  REGIONS_RATING_INCOME_MUL_1  \
# 61080       170832                      0.137633                    -0.025011
# 199483      331264                      0.397922                    -0.072486
#
#         EMERGENCYSTATE_MODE_0  \
# 61080               -1.033695
# 199483              -1.033695
#
#         CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 61080                                            0.000000
# 199483                                          -0.020491
#
#         REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 61080                 0.113357         2.004021
# 199483                0.113357        -0.498997
#
#         CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  \
# 61080                                            0.000000         -0.548348
# 199483                                          -0.023502          1.295580
#
#         FLAG_DOCUMENT_3  ...  \
# 61080          0.639051  ...
# 199483        -1.564821  ...
#
#         CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  EXT_SOURCE_VAR  \
# 61080                                            0.000000          -0.874456
# 199483                                           0.011009           0.435226
#
#         AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  NAME_YIELD_GROUP_LAST_LAST_5  \
# 61080                          -0.304546                     -1.036849
# 199483                         -0.304546                     -1.036849
#
#         LIVE_CITY_NOT_WORK_CITY  \
# 61080                 -0.467818
# 199483                 2.137584
#
#         ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 61080                                            0.514445
# 199483                                          -1.594849
#
#         AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE
# 61080          -0.142532    0.747770     -0.577534         0.978767
# 199483         -0.047645   -0.649773     -0.577534        -0.543780
#
# [2 rows x 54 columns]

# %%
y = y_shap
y.head(2)
# Out:
# 61080     0
# 199483    0
# Name: TARGET, dtype: int64

# %%
# transform the dataset
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
display(X.head(2))
display(X.shape)
display(y.head(2))
display(y.shape)
# Out:
#    SK_ID_CURR  WEEKDAY_APPR_PROCESS_START_1  REGIONS_RATING_INCOME_MUL_1  \
# 0      170832                      0.137633                    -0.025011
# 1      331264                      0.397922                    -0.072486
#
#    EMERGENCYSTATE_MODE_0  \
# 0              -1.033695
# 1              -1.033695
#
#    CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 0                                           0.000000
# 1                                          -0.020491
#
#    REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 0                0.113357         2.004021
# 1                0.113357        -0.498997
#
#    CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  \
# 0                                           0.000000         -0.548348
# 1                                          -0.023502          1.295580
#
#    FLAG_DOCUMENT_3  ...  CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  \
# 0         0.639051  ...                                           0.000000
# 1        -1.564821  ...                                           0.011009
#
#    EXT_SOURCE_VAR  AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  \
# 0       -0.874456                         -0.304546
# 1        0.435226                         -0.304546
#
#    NAME_YIELD_GROUP_LAST_LAST_5  LIVE_CITY_NOT_WORK_CITY  \
# 0                     -1.036849                -0.467818
# 1                     -1.036849                 2.137584
#
#    ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                           0.514445
# 1                                          -1.594849
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE
# 0         -0.142532    0.747770     -0.577534         0.978767
# 1         -0.047645   -0.649773     -0.577534        -0.543780
#
# [2 rows x 54 columns]
# (18326, 54)
# 0    0
# 1    0
# Name: TARGET, dtype: int64
# (18326,)

# %%
y.value_counts()
# Out:
# 0    9163
# 1    9163
# Name: TARGET, dtype: int64

# %% [markdown]
# -----------------------------------------------------------------

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import shap

# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
d_train = lgb.Dataset(X_train, label=y_train)
d_test = lgb.Dataset(X_test, label=y_test)

# %%
display(X_train.head(2))
display(X_train.shape)
display(y_train.head(2))
display(y_train.shape)
display(X_test.head(2))
display(X_test.shape)
display(y_test.head(2))
display(y_test.shape)
# Out:
#        SK_ID_CURR  WEEKDAY_APPR_PROCESS_START_1  REGIONS_RATING_INCOME_MUL_1  \
# 16770      402850                      1.439078                     0.909038
# 12583      146850                      1.439078                    -0.046543
#
#        EMERGENCYSTATE_MODE_0  \
# 16770              -0.063803
# 12583               0.963572
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 16770                                          -0.020491
# 12583                                          -0.020491
#
#        REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 16770               -0.914774         0.716493
# 12583                0.113357         1.694416
#
#        CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  \
# 16770                                          -0.011413         -0.548348
# 12583                                          -0.002907         -0.320267
#
#        FLAG_DOCUMENT_3  ...  \
# 16770        -0.431170  ...
# 12583         0.639051  ...
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  EXT_SOURCE_VAR  \
# 16770                                           0.011009           0.656325
# 12583                                           0.011009          -0.290946
#
#        AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  NAME_YIELD_GROUP_LAST_LAST_5  \
# 16770                          0.380573                     -0.533345
# 12583                         -0.217217                      1.384824
#
#        LIVE_CITY_NOT_WORK_CITY  \
# 16770                -0.467818
# 12583                -0.467818
#
#        ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 16770                                          -0.509848
# 12583                                          -0.599042
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE
# 16770          0.081374    0.552618     -0.577534         0.683455
# 12583         -0.095584    0.072786      0.635990        -0.239271
#
# [2 rows x 54 columns]
# (12828, 54)
# 16770    1
# 12583    1
# Name: TARGET, dtype: int64
# (12828,)
#        SK_ID_CURR  WEEKDAY_APPR_PROCESS_START_1  REGIONS_RATING_INCOME_MUL_1  \
# 1150       168383                     -0.747350                    -0.025011
# 14284      191454                     -1.214288                     0.092322
#
#        EMERGENCYSTATE_MODE_0  \
# 1150                0.963572
# 14284              -0.309351
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE  \
# 1150                                           -0.020491
# 14284                                          -0.013060
#
#        REGION_RATING_CLIENT_0  FLAG_WORK_PHONE  \
# 1150                 0.113357        -0.498997
# 14284                0.113357         0.408767
#
#        CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED  FLAG_REGIONS  \
# 1150                                                 0.0          1.295580
# 14284                                                0.0          0.626847
#
#        FLAG_DOCUMENT_3  ...  \
# 1150          0.639051  ...
# 14284        -0.765548  ...
#
#        CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE  EXT_SOURCE_VAR  \
# 1150                                            0.011009           0.395514
# 14284                                           0.007016           0.937563
#
#        AMT_CREDIT_SUM_DEBT_MEAN_OVERALL  NAME_YIELD_GROUP_LAST_LAST_5  \
# 1150                           0.298495                       0.89914
# 14284                         -0.242899                       1.13318
#
#        LIVE_CITY_NOT_WORK_CITY  \
# 1150                  2.137584
# 14284                 1.192689
#
#        ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 1150                                            0.514445
# 14284                                          -0.295387
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  CNT_CHILDREN  AMT_GOODS_PRICE
# 1150          -0.142532   -1.108615      0.807282        -1.091897
# 14284         -0.049517    0.266073     -0.577534         0.172166
#
# [2 rows x 54 columns]
# (5498, 54)
# 1150     0
# 14284    1
# Name: TARGET, dtype: int64
# (5498,)

# %%
# Former le modele
params = {
    "max_bin": 512,
    "learning_rate": 0.05,
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "binary_logloss",
    "num_leaves": 10,
    "verbose": -1,
    "min_data": 100,
    "boost_from_average": True
}

model = lgb.train(params, d_train, 10000, valid_sets=[d_test], early_stopping_rounds=50, verbose_eval=1000)
# Out:
# Training until validation scores don't improve for 50 rounds
# [1000]	valid_0's binary_logloss: 0.0548614
# [2000]	valid_0's binary_logloss: 0.0220973
# [3000]	valid_0's binary_logloss: 0.00932324
# [4000]	valid_0's binary_logloss: 0.00406812
# [5000]	valid_0's binary_logloss: 0.00184473
# [6000]	valid_0's binary_logloss: 0.000826259
# [7000]	valid_0's binary_logloss: 0.000374526
# [8000]	valid_0's binary_logloss: 0.000168072
# [9000]	valid_0's binary_logloss: 7.69631e-05
# [10000]	valid_0's binary_logloss: 3.50702e-05
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's binary_logloss: 3.50702e-05

# %%
# Librairie Pycaret
# import pycaret
# from pycaret.classification import *
# from pycaret.utils import check_metric
# from sklearn.metrics import log_loss
# model  =  load_model ( 'Save_Model/Final LightGbm Model 23sept2021' )

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
len(shap_values)
# Out:
# 2

# %%
single = X[X['SK_ID_CURR'] == 455401]
single
# Out:
# Empty DataFrame
# Columns: [SK_ID_CURR, WEEKDAY_APPR_PROCESS_START_1, REGIONS_RATING_INCOME_MUL_1, EMERGENCYSTATE_MODE_0, CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE, REGION_RATING_CLIENT_0, FLAG_WORK_PHONE, CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED, FLAG_REGIONS, FLAG_DOCUMENT_3, CREDIT_EXT_RATIO, OBS_60_CREDIT_RATIO, FLAG_CONTACTS_SUM, WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2, SK_DPD_DEF_MAX_YEAR_REST_MEAN, AMT_INCOME_TOTAL_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY, WEEKDAY_APPR_PROCESS_START_MAX_ALL, AMT_CREDIT_SUM_LIMIT_MAX_CREDITACTIVE_ACTIVE, DAYS_ID_PUBLISH, FLAG_PHONE, DAYS_BIRTH, EXT_SOURCE_MIN, AMT_PAYMENT_RATIO_MIN_LAST_1_YEAR, WEIGHTED_EXT_SOURCE, OBS_30_CNT_SOCIAL_CIRCLE, CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL, INSTALLMENTS_ANNUITY_AMT_INSTALMENT_MEAN_MAX_RATIO, NAME_EDUCATION_TYPE_1, CREDIT_GOODS_DIFF, AMT_ANNUITY_CREDIT_RATIO_MEAN_OVERALL, AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE, AMT_PAYMENT_DIFF_MAX_LAST_1_YEAR, CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_CLOSED, OCCUPATION_TYPE_0, CAR_EMPLOYED_RATIO, ORGANIZATION_TYPE_1, AMT_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS, NAME_CONTRACT_STATUS_MEAN_ALL, NAME_TYPE_SUITE_LAST_FIRST_2, AMT_CREDIT_SUM_SUM_CREDITACTIVE_ACTIVE, AMT_ANNUITY_SUM_CREDITACTIVE_CLOSED, EXT_SOURCE_2, CREDIT_TYPE_Car loan_MEAN_OVERALL, AMT_ANNUITY, CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE, EXT_SOURCE_VAR, AMT_CREDIT_SUM_DEBT_MEAN_OVERALL, NAME_YIELD_GROUP_LAST_LAST_5, LIVE_CITY_NOT_WORK_CITY, ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY, AMT_INCOME_TOTAL, AMT_CREDIT, CNT_CHILDREN, AMT_GOODS_PRICE]
# Index: []
#
# [0 rows x 54 columns]

# %%
# test_shap

# %%
shap.summary_plot(shap_values, single, max_display=10, plot_type ="bar", color_bar=False)
# shap.summary_plot(shap_values[0], X, plot_type ="bar", max_display=number, color_bar=False, plot_size=(5, 5))

# %% [markdown]
# **SHAP VALUES - FEATURES IMPORTANCES - XGBOOST**

# %%
from sklearn.model_selection import train_test_split
import xgboost
import shap
import numpy as np
import matplotlib.pylab as pl

# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# **Jeux de données**

# %%
train_df_std_sample = pd.read_csv('data_tableau_xgb/train_df_std_sample.csv').drop('Unnamed: 0', axis=1)
train_df_sample = pd.read_csv('data_tableau_xgb/train_df_sample.csv').drop('Unnamed: 0', axis=1)
test_df_std_sample = pd.read_csv('data_tableau_xgb/test_df_std_sample.csv').drop('Unnamed: 0', axis=1)
test_df_sample = pd.read_csv('data_tableau_xgb/test_df_sample.csv').drop('Unnamed: 0', axis=1)

print('train_df_std_sample : ', train_df_std_sample.shape)
print('train_df_sample : ', train_df_sample.shape)
print('test_df_std_sample : ', test_df_std_sample.shape)
print('test_df_sample : ', test_df_sample.shape)
# Out:
# train_df_std_sample :  (10000, 1243)
# train_df_sample :  (10000, 1246)
# test_df_std_sample :  (10000, 1242)
# test_df_sample :  (10000, 1245)

# %%
train_shape  = train_df_std_sample.drop(['TARGET_NEIGHBORS_500_MEAN', 'TARGET'], axis=1)
test_shape = test_df_std_sample.drop(['TARGET_NEIGHBORS_500_MEAN'], axis=1)
y_shape = train_df_std_sample['TARGET']

# %%
print('train_shape : ', train_shape.shape)
print('test_shape : ', test_shape.shape)
print('y_shape : ', y_shape.shape)
# Out:
# train_shape :  (10000, 1241)
# test_shape :  (10000, 1241)
# y_shape :  (10000,)

# %%
selection_clients = test_df_std_sample['SK_ID_CURR']
selection_clients = pd.DataFrame(selection_clients)
selection_clients.columns = ['ID']
selection_clients.head(2)
# Out:
#        ID
# 0  100001
# 1  100005

# %%
# Sauvegarde selection_clients
selection_clients.to_csv('data_tableau_xgb/selection_clients.csv')

# %%
X = train_shape
y = y_shape

# %%
# Sauvegarde des jeux shape pour le dashboard streamlit
train_shape.to_csv('data_tableau_xgb/train_shape.csv')
test_shape.to_csv('data_tableau_xgb/test_shape.csv')
y_shape.to_csv('data_tableau_xgb/y_shape.csv')

# %%
from xgboost import XGBClassifier, plot_importance
model = XGBClassifier()
model.fit(X, y)
# Out:
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [14:06:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
import numpy as np
sorted_idx = np.argsort(model.feature_importances_)[::-1]
len(sorted_idx)
# Out:
# 1241

# %%
for index in sorted_idx:
    print([X.columns[index]], model.feature_importances_[index])
# Out:
# ['CREDIT_DOWNPAYMENT_RATIO_MEAN_FIRST_2'] 0.010679367
# ['EXT_SOURCE_2_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.006428167
# ['NAME_SELLER_INDUSTRY_MEAN_LAST_5'] 0.005510135
# ['AMT_CREDIT_SUM_LIMIT_MAX_CREDITACTIVE_ACTIVE'] 0.0053064795
# ['EXP_POS_TOTAL_TERM_LAST_YEAR_0_MEAN'] 0.0051544285
# ['AMT_CREDIT_GOODS_DIFF_SUM_ALL'] 0.0050085597
# ['CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL'] 0.0044085146
# ['NUM_INSTALMENT_VERSION_SUM_MEAN'] 0.004391201
# ['AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_CLOSED'] 0.00416099
# ['APARTMENTS_MEDI'] 0.0040137772
# ['EXT_SOURCE_1_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.003815529
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE_INCOME_RATIO'] 0.0037946003
# ['TOTAL_TERM_MEAN_YEAR_0_SUM'] 0.0036806813
# ['AMT_CREDIT_SUM_DEBT_SUM_CREDITACTIVE_CLOSED'] 0.003627363
# ['INCOME_APARTMENT_MODE_MUL'] 0.0036259657
# ['FLAG_DOCUMENT_19'] 0.003605253
# ['SK_DPD_RATIO_MEAN_MEAN'] 0.00356781
# ['BUREAU_AMT_CREDIT_SUM_OVERDUE_MAX_CREDITACTIVE_ACTIVE_INCOME_RATIO'] 0.0035190263
# ['NAME_PRODUCT_TYPE_MEAN_LAST_5'] 0.0035001864
# ['AMT_CREDIT_GOODS_DIFF_MIN_FIRST_2'] 0.003423188
# ['EXP_ENCODED_STATUS_LAST_YEAR_REST_MEAN_OVERALL'] 0.0033518672
# ['AMT_CREDIT_SUM_MEAN_OVERALL'] 0.0033333355
# ['SK_DPD_SUM_YEAR_REST'] 0.0032980244
# ['WEIGHTED_STATUS_MEAN_MAX_CREDITACTIVE_ACTIVE'] 0.0032730435
# ['CNT_INSTALMENT_MIN_YEAR_0_MEAN'] 0.0032479884
# ['AMT_CREDIT_MAX_FIRST_2'] 0.00323335
# ['EXP_AMT_PAYMENT_RATIO_LAST_LAST_1_YEAR'] 0.0032062712
# ['CNT_DRAWINGS_ATM_CURRENT_SUM'] 0.0032060682
# ['AMT_CREDIT_SUM_MAXCREDIT_ACTIVE_REST'] 0.003157807
# ['INSTALLMENTS_AMT_PAYMENT_MAX_LAST_1_YEAR_INCOME_RATIO'] 0.0031446845
# ['AMT_INST_MIN_REGULARITY_MAX'] 0.0031056534
# ['APARTMENTS_SUM_AVG_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0030372613
# ['AMT_CREDIT_SUM_MAX_CREDITACTIVE_CLOSED'] 0.0030349158
# ['GOOD_DOWNPAYMET_RATIO_MAX_LAST_5'] 0.0029512912
# ['AMT_CREDIT_SUM_LIMIT_MEAN_OVERALL'] 0.00295051
# ['BUREAU_DAYS_CREDIT_MINCREDIT_ACTIVE_REST_REGISTRATION_DIFF'] 0.0029052536
# ['YEARS_BUILD_MODE'] 0.002874735
# ['AMT_PAYMENT_DIFF_MAX_MEAN'] 0.0028575705
# ['BASEMENTAREA_MEDI'] 0.0028311443
# ['AMT_ANNUITY_MEAN_OVERALL'] 0.0028259873
# ['MIN_PAYMENT_RATIO_MIN_YEAR_1'] 0.0027720355
# ['CAR_EMPLOYED_DIFF'] 0.002755994
# ['SK_DPD_RATIO_MEAN'] 0.00275192
# ['APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5'] 0.002751243
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5'] 0.0027234247
# ['HOUSETYPE_MODE_0'] 0.0026919595
# ['TOTAL_TERM_MEAN_SUM'] 0.0026915194
# ['ENTRANCES_MEDI'] 0.0026859965
# ['NAME_PRODUCT_TYPE_MEAN_FIRST_2'] 0.0026741556
# ['EXPECTED_INTEREST_SHARE'] 0.0026397507
# ['CAR_AGE_RATIO'] 0.0026321553
# ['DAYS_DECISION_MEAN_LAST_5'] 0.0026179473
# ['AMT_DRAWINGS_CURRENT_SUM'] 0.0025981886
# ['TOTAL_TERM_MEAN_YEAR_1_SUM'] 0.0025732087
# ['LANDAREA_MEDI'] 0.00255919
# ['MIN_PAYMENT_RATIO_MIN_YEAR_0'] 0.0025333536
# ['TOTAL_TERM_MEAN_REST_MAX'] 0.00253175
# ['AMT_CREDIT_SUM_LIMIT_SUM_CREDITACTIVE_CLOSED'] 0.0025184692
# ['WEIGHTED_STATUS_MAX_YEAR_REST_MEAN_OVERALL'] 0.0025157297
# ['AMT_ANNUITY_MAX_CREDITACTIVE_ACTIVE'] 0.0025017546
# ['PREV_AMT_GOODS_PRICE_SUM_FIRST_2_INCOME_RATIO'] 0.0024795362
# ['FLAG_WORK_PHONE'] 0.0024481984
# ['EXT_SOURCE_1_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0024442372
# ['CNT_INSTALMENT_FUTURE_MAX_YEAR_0_MEAN'] 0.0024337778
# ['NAME_TYPE_SUITE_1'] 0.002433352
# ['AMT_GOODS_PRICE_MAX_ALL'] 0.0024140084
# ['ANNUITY_MEAN_LAST_5'] 0.0024081222
# ['EXT_SOURCE_MEAN'] 0.0023992509
# ['APARTMENTS_SUM_MEDI_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0023987552
# ['EXT_SOURCE_3_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0023941225
# ['AMT_ANNUITY_MAX_ALL'] 0.0023932576
# ['DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED'] 0.0023878156
# ['EXT_SOURCE_2_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0023843877
# ['AMT_ANNUITY_SUM_LAST_5'] 0.0023812945
# ['DAYS_FIRST_LAST_DUE_DIFF_MAX_ALL'] 0.0023794526
# ['AMT_CREDIT_SUM_OVERDUE_SUM_CREDITACTIVE_ACTIVE'] 0.0023653614
# ['DAYS_CREDIT_MAXCREDIT_ACTIVE_REST'] 0.0023544712
# ['MISSING_VALS_TOTAL_INSTAL_SUM_SUM'] 0.0023140223
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_CLOSED_INCOME_RATIO'] 0.002313673
# ['DAYS_PAYMENT_RATIO_MEAN_FIRST_5_INSTALLMENTS'] 0.0023107254
# ['EXP_DAYS_PAYMENT_RATIO_LAST_FIRST_5_INSTALLMENTS'] 0.0022934214
# ['DAYS_CREDIT_MIN_CREDITACTIVE_ACTIVE'] 0.0022929325
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_1_SUM'] 0.0022763384
# ['FLAG_EMP_PHONE'] 0.002275632
# ['CREDIT_ANNUITY_RATIO'] 0.0022712643
# ['TOTAL_TERM_MEAN_ACTIVE_MAX'] 0.0022654093
# ['EXP_PAYMENT_MIN_DIFF_LAST_YEAR_REST'] 0.0022522502
# ['FLAG_MOBIL'] 0.0022477228
# ['CNT_INSTALMENT_MEAN_YEAR_0_MAX'] 0.002228164
# ['FLAG_DOCUMENT_17'] 0.0022254859
# ['AMT_INTEREST_SUM_ALL'] 0.002210467
# ['EXP_MIN_PAYMENT_RATIO_LAST_YEAR_REST'] 0.0021954179
# ['CHANNEL_TYPE_LAST_LAST_5'] 0.0021824928
# ['DAYS_TERMINATION_MAX_FIRST_2'] 0.0021801395
# ['AMT_ANNUITY_SUM_ALL'] 0.0021648642
# ['AMT_ANNUITY_CREDIT_RATIO_MEANCREDIT_ACTIVE_REST'] 0.0021631536
# ['APARTMENTS_SUM_AVG'] 0.0021566532
# ['WEEKDAY_APPR_PROCESS_START_0'] 0.0021459744
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_COMPLETED_MEAN'] 0.0021404077
# ['AMT_DRAWINGS_ATM_CURRENT_SUM'] 0.00213267
# ['AMT_ANNUITY_MAX_LAST_5'] 0.002130335
# ['EXT_SOURCE_3_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0021090035
# ['DAYS_LAST_DUE_MEAN_ALL'] 0.0021013496
# ['DAYS_PAYMENT_DIFF_MEAN_FIRST_5_INSTALLMENTS'] 0.0020987766
# ['AMT_DOWN_PAYMENT_SUM_LAST_5'] 0.002091283
# ['CONTRACT_Active'] 0.0020877223
# ['AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2'] 0.0020840429
# ['OBS_30_CREDIT_RATIO'] 0.0020782568
# ['AGE_EMPLOYED_DIFF_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.002075477
# ['AMT_PAYMENT_RATIO_MEAN_FIRST_5_INSTALLMENTS'] 0.0020752437
# ['NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2'] 0.0020696619
# ['INTEREST_CREDIT_PRIVILEGED_SUM_FIRST_2'] 0.0020684558
# ['NAME_HOUSING_TYPE_1'] 0.0020492524
# ['CONTRACT_COMPLETED_MEAN'] 0.0020309994
# ['AMT_INCOME_TOTAL_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0020277717
# ['EXT_SOURCE_2_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0020269924
# ['AMT_ANNUITY_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0020235875
# ['CNT_INSTALMENT_FUTURE_MEAN_REST_MEAN'] 0.0020233064
# ['OWN_CAR_AGE'] 0.002013118
# ['NAME_EDUCATION_TYPE_1'] 0.002009168
# ['AMT_CREDIT_YIELD_GROUP_MEAN_LAST_5'] 0.0020089147
# ['EXP_CNT_INSTALMENT_LAST_YEAR_0_MEAN'] 0.0020047203
# ['SK_DPD_DEF_SUM_MEAN'] 0.0020024267
# ['RATE_DOWN_PAYMENT_MEAN_ALL'] 0.0019931465
# ['AMT_CREDIT_MAX_OVERDUE_MEAN_OVERALL'] 0.0019923747
# ['NAME_CONTRACT_STATUS_LAST_LAST_5'] 0.001957074
# ['HOUR_APPR_PROCESS_START_MIN_FIRST_2'] 0.0019566698
# ['NAME_CLIENT_TYPE_MEAN_LAST_5'] 0.0019405086
# ['CNT_PROLONGED_MAX_OVERDUE_MUL_MAX_CREDITACTIVE_CLOSED'] 0.0019336327
# ['AMT_CREDIT_SUM_DEBT_SUM_CREDITACTIVE_ACTIVE'] 0.0019217492
# ['EXT_SOURCE_3_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0019192769
# ['AMT_DECLINED_SUM_ALL'] 0.0019084116
# ['SK_DPD_MAX_YEAR_0_MEAN'] 0.0019068411
# ['SK_ID_CURR'] 0.0018993889
# ['DAYS_FIRST_LAST_DUE_DIFF_MEAN_FIRST_2'] 0.0018990728
# ['INTEREST_DOWNPAYMENT_MAX_LAST_5'] 0.0018901759
# ['PREV_AMT_ANNUITY_MEAN_ALL_INCOME_RATIO'] 0.0018892775
# ['EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_REST'] 0.0018880427
# ['FLAG_CONT_MOBILE'] 0.0018839985
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE'] 0.0018811851
# ['AMT_CREDIT_GOODS_DIFF_MAX_FIRST_2'] 0.0018726272
# ['SELLERPLACE_AREA_MIN_FIRST_2'] 0.0018686926
# ['EXT_SOURCE_1_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0018676001
# ['EXP_PAYMENT_MIN_DIFF_LAST_ACTIVE'] 0.0018606357
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_REST_MAX'] 0.0018580453
# ['TOTAL_TERM_MEAN_YEAR_0_MEAN'] 0.0018575423
# ['AMT_INTEREST_RECEIVABLE_MEAN_YEAR_REST'] 0.0018537055
# ['EXT_SOURCE_2_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0018508724
# ['AMT_INCOME_TOTAL_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0018493674
# ['AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2'] 0.0018492592
# ['CNT_INSTALMENT_MEAN_REST_MEAN'] 0.0018489854
# ['EXP_DAYS_PAYMENT_DIFF_LAST_MEAN'] 0.0018484009
# ['AMT_DOWN_PAYMENT_MEAN_LAST_5'] 0.0018481703
# ['REGIONS_RATING_INCOME_MUL_1'] 0.0018467557
# ['DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR'] 0.0018447094
# ['DAYS_PAYMENT_DIFF_MIN_FIRST_5_INSTALLMENTS'] 0.0018445504
# ['SK_DPD_SUM_YEAR_0_MEAN'] 0.0018363392
# ['BALANCE_LIMIT_RATIO_MEAN_YEAR_0'] 0.001833945
# ['APARTMENTS_SUM_AVG_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0018234041
# ['INSTALLMENTS_AMT_PAYMENT_MAX_MEAN_INCOME_RATIO'] 0.0018164186
# ['DAYS_PAYMENT_RATIO_MAX_MAX'] 0.0018075153
# ['EXP_AMT_PAYMENT_DIFF_LAST_MEAN'] 0.0018059853
# ['CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_ACTIVE'] 0.0018046914
# ['CAR_EMPLOYED_RATIO'] 0.0017983088
# ['INTEREST_DOWNPAYMENT_MEAN_LAST_5'] 0.0017844597
# ['REGIONS_RATING_INCOME_MUL_0'] 0.0017839149
# ['AMT_ANNUITY_CREDIT_RATIO_MEAN_CREDITACTIVE_ACTIVE'] 0.001783168
# ['EXT_SOURCE_2_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0017810154
# ['BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED_EMPLOYED_DIFF'] 0.0017800732
# ['AMT_CREDIT_LIMIT_ACTUAL_SUM'] 0.0017760326
# ['AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL'] 0.0017750977
# ['STATUS_LAST_YEAR_REST_MEAN_OVERALL'] 0.0017675156
# ['AMT_INSTALMENT_SUM_MAX'] 0.001764172
# ['SK_DPD_DEF_SUM_YEAR_1_MEAN'] 0.0017635599
# ['AMT_INTEREST_RECEIVABLE_MIN'] 0.0017577796
# ['AMT_ANNUITY_SUM_FIRST_2'] 0.0017562216
# ['AMT_CREDIT_SUM_OVERDUE_MAX_CREDITACTIVE_ACTIVE'] 0.0017411995
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_ACTIVE_MEAN'] 0.0017374095
# ['AMT_DRAWINGS_CURRENT_MAX'] 0.0017337177
# ['WEIGHTED_STATUS_LAST_YEAR_REST_MEAN_OVERALL'] 0.0017317475
# ['CC_AMT_RECIVABLE_MEAN_INCOME_RATIO'] 0.0017309298
# ['LIVINGAPARTMENTS_MODE'] 0.0017259303
# ['CNT_NON_CHILDREN'] 0.0017248286
# ['RATE_DOWN_PAYMENT_MEAN_FIRST_2'] 0.0017247968
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_ALL'] 0.0017193678
# ['EXP_WEIGHTED_STATUS_LAST_YEAR_1_MEAN_OVERALL'] 0.001706169
# ['APARTMENTS_SUM_MEDI_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0017058834
# ['CURRENT_CREDIT_DEBT_DIFF_MIN_CREDITACTIVE_CLOSED'] 0.0016964168
# ['AMT_PAYMENT_DIFF_MAX_LAST_1_YEAR'] 0.0016958134
# ['AMT_DRAWINGS_OTHER_CURRENT_SUM'] 0.0016953171
# ['EXP_BALANCE_LIMIT_RATIO_LAST'] 0.0016935166
# ['AMT_INSTALMENT_SUM_MEAN'] 0.0016856214
# ['EXP_CNT_INSTALMENT_LAST_ACTIVE_MEAN'] 0.0016841231
# ['SK_DPD_MAX_MEAN'] 0.0016775843
# ['TOTAL_TERM_MEAN_YEAR_0_MAX'] 0.0016766902
# ['DAYS_CREDIT_MINCREDIT_ACTIVE_REST'] 0.001675117
# ['RATE_DOWN_PAYMENT_MEAN_LAST_5'] 0.0016711182
# ['DAYS_BIRTH'] 0.0016637017
# ['REGION_RATING_CLIENT_W_CITY_0'] 0.001660703
# ['CURRENT_CREDIT_DEBT_DIFF_MEANCREDIT_ACTIVE_REST'] 0.0016555918
# ['INTEREST_SHARE_MEAN_ALL'] 0.00165481
# ['NAME_YIELD_GROUP_MEAN_FIRST_2'] 0.0016494718
# ['ANNUITY_GOODS_SUM_ALL'] 0.0016473037
# ['MISSING_VALS_TOTAL_APP'] 0.0016466109
# ['NFLAG_INSURED_ON_APPROVAL_SUM_ALL'] 0.0016428264
# ['STATUS_MEAN_MEAN_CREDITACTIVE_CLOSED'] 0.0016381308
# ['BUREAU_DAYS_CREDIT_MIN_CREDITACTIVE_CLOSED_REGISTRATION_DIFF'] 0.0016162654
# ['PREV_AMT_GOODS_PRICE_MAX_FIRST_2_INCOME_RATIO'] 0.0016106075
# ['SK_DPD_SUM_YEAR_1_MEAN'] 0.0016084131
# ['INSTALLMENTS_AMT_PAYMENT_MEAN_MAX_INCOME_RATIO'] 0.001605618
# ['EXT_SOURCE_2_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0016039419
# ['NUM_INSTALMENT_NUMBER_MAX_MEAN'] 0.0016032626
# ['AMT_CREDIT_GOODS_DIFF_MAX_LAST_5'] 0.0016027605
# ['AMT_PAYMENT_RATIO_MIN_MIN'] 0.0016017334
# ['CNT_INSTALMENT_MEAN_YEAR_1_MEAN'] 0.0015936221
# ['NAME_CLIENT_TYPE_MEAN_FIRST_2'] 0.0015934827
# ['EXT_SOURCE_MEAN_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0015917862
# ['AMT_CREDIT_GOODS_RATIO_MAX_ALL'] 0.0015851472
# ['AMT_CREDIT_MAX_OVERDUE_MAXCREDIT_ACTIVE_REST'] 0.0015843579
# ['PREV_AMT_ANNUITY_MEAN_LAST_5_INCOME_RATIO'] 0.0015740449
# ['TOTAL_TERM_MEAN_COMPLETED_SUM'] 0.0015654728
# ['CREDIT_TYPE_Loan for business development_MEAN_OVERALL'] 0.0015641582
# ['AMT_CREDIT_GOODS_RATIO_MIN_FIRST_2'] 0.0015596692
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0015586781
# ['EXT_SOURCE_3_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0015515345
# ['CHANNEL_TYPE_MEAN_ALL'] 0.0015494559
# ['DAYS_TERMINATION_MEAN_FIRST_2'] 0.0015357008
# ['ANNUITY_INCOME_RATIO_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0015246852
# ['EXT_SOURCE_2_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0015246852
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0015195427
# ['SK_DPD_RATIO_MEAN_YEAR_1_SUM'] 0.0015182387
# ['ANNUITY_INCOME_RATIO_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0015164464
# ['AMT_GOODS_PRICE'] 0.0015037175
# ['CREDIT_TYPE_Credit card_MEAN_OVERALL'] 0.0014980092
# ['TOTAL_TERM_MEAN_MAX'] 0.0014955743
# ['CURRENT_CREDIT_DEBT_DIFF_MINCREDIT_ACTIVE_REST'] 0.001495382
# ['APARTMENTS_SUM_AVG_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.001491256
# ['NAME_INCOME_TYPE_0'] 0.0014882059
# ['NAME_PRODUCT_TYPE_MEAN_ALL'] 0.0014878917
# ['PRODUCT_COMBINATION_LAST_LAST_5'] 0.0014858827
# ['DAYS_PAYMENT_RATIO_MEAN_MIN'] 0.0014845947
# ['DAYS_DECISION_MAX_FIRST_2'] 0.0014804333
# ['MIN_PAYMENT_TOTAL_RATIO_MEAN'] 0.0014790179
# ['AMT_PAYMENT_RATIO_MEAN_LAST_1_YEAR'] 0.0014775859
# ['AMT_CREDIT_GOODS_RATIO_MEAN_FIRST_2'] 0.0014752687
# ['APARTMENTS_AVG'] 0.0014702856
# ['CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL'] 0.0014607675
# ['CNT_DRAWING_SUM_MAX_ACTIVE'] 0.0014604785
# ['HOUR_APPR_PROCESS_START_MIN_LAST_5'] 0.0014566979
# ['AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_LAST_5'] 0.0014489733
# ['DAYS_LAST_DUE_1ST_VERSION_MEAN_ALL'] 0.0014487013
# ['DAYS_PAYMENT_RATIO_MAX_MEAN'] 0.0014466837
# ['REGION_POPULATION_RELATIVE'] 0.0014441218
# ['EXT_SOURCE_2_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.001443535
# ['AMT_DOWN_PAYMENT_MEAN_FIRST_2'] 0.001439438
# ['DAYS_ID_PUBLISH'] 0.0014266153
# ['INSTALLMENTS_ANNUITY_AMT_INSTALMENT_MEAN_MAX_RATIO'] 0.0014259148
# ['AMT_INTEREST_MIN_ALL'] 0.0014256182
# ['INSTALLMENTS_AMT_PAYMENT_MAX_FIRST_5_INSTALLMENTS_INCOME_RATIO'] 0.0014253156
# ['CC_AMT_RECEIVABLE_PRINCIPAL_SUM_INCOME_RATIO'] 0.0014226371
# ['CNT_INSTALMENT_MEAN_COMPLETED_MAX'] 0.0014170085
# ['DAYS_CREDIT_MAX_CREDITACTIVE_ACTIVE'] 0.0014153104
# ['ANNUITY_INCOME_RATIO_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0014116986
# ['EXT_SOURCE_3_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0014069487
# ['FLAG_CONTACTS_SUM'] 0.0014053707
# ['EXP_AMT_INTEREST_RECEIVABLE_LAST_ACTIVE'] 0.0014038824
# ['DAYS_LAST_DUE_1ST_VERSION_MEAN_FIRST_2'] 0.0013952341
# ['CNT_PROLONGED_DURATION_RATIO_MEAN_OVERALL'] 0.0013932489
# ['FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5'] 0.0013883353
# ['AMT_INTEREST_RECEIVABLE_MIN_ACTIVE'] 0.0013862541
# ['STATUS_LAST_YEAR_0_MEAN_OVERALL'] 0.0013845493
# ['PRODUCT_COMBINATION_MEAN_ALL'] 0.0013728897
# ['BUREAU_DAYS_CREDIT_LAST_CREDITACTIVE_ACTIVE_REGISTRATION_DIFF'] 0.0013686353
# ['AMT_BALANCE_SUM'] 0.0013674009
# ['CNT_PAYMENT_MAX_ALL'] 0.0013672858
# ['FLAG_DOCUMENT_15'] 0.0013587754
# ['CNT_INSTALMENT_FUTURE_MIN_MEAN'] 0.001353017
# ['EXP_BALANCE_LIMIT_RATIO_LAST_COMPLETED'] 0.0013443897
# ['CONTRACT_RETURNED TO THE STORE_MEAN'] 0.0013402438
# ['NAME_PORTFOLIO_MEAN_FIRST_2'] 0.0013400969
# ['EXP_PAYMENT_MIN_DIFF_LAST'] 0.001339378
# ['BALANCE_LIMIT_RATIO_MEAN_ACTIVE'] 0.0013376306
# ['EXP_DAYS_PAYMENT_RATIO_LAST_MEAN'] 0.0013373337
# ['SELLERPLACE_AREA_MEAN_LAST_5'] 0.0013352126
# ['COMMONAREA_AVG'] 0.0013286141
# ['DAYS_PAYMENT_DIFF_MEAN_LAST_1_YEAR'] 0.0013253872
# ['WEEKDAY_APPR_PROCESS_START_MIN_ALL'] 0.0013245287
# ['INSTALLMENTS_AMT_PAYMENT_MEAN_MEAN_INCOME_RATIO'] 0.0013151738
# ['EXP_SK_DPD_RATIO_LAST_YEAR_1'] 0.0013119305
# ['ANNUITY_GOODS_MAX_FIRST_2'] 0.0013091502
# ['AMT_INTEREST_RECEIVABLE_MIN_YEAR_REST'] 0.0013087686
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_CREDITACTIVE_CLOSED'] 0.0013079792
# ['MISSING_VALUES_TOTAL_PREV_SUM_ALL'] 0.0013079506
# ['APARTMENTS_SUM_MEDI'] 0.0013073994
# ['BALANCE_LIMIT_RATIO_MAX_YEAR_0'] 0.0013037976
# ['AMT_ANNUITY_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0013023097
# ['AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_LAST_5'] 0.001298944
# ['STATUS_MAX_MEAN_OVERALL'] 0.0012975946
# ['CURRENCY_currency 1_MEAN_OVERALL'] 0.0012921174
# ['ANNUITY_MEAN_ALL'] 0.001291586
# ['CREDIT_DAY_OVERDUE_MEAN_CREDITACTIVE_CLOSED'] 0.0012845568
# ['SUM_OBS_DEF_ALL'] 0.0012831086
# ['MISSING_VALUES_TOTAL_PREV_SUM_LAST_5'] 0.0012830747
# ['EXT_SOURCE_MEAN_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0012786965
# ['CNT_INSTALMENT_MAX_MEAN'] 0.0012743864
# ['AMT_APPLICATION_MEAN_FIRST_2'] 0.0012674681
# ['WEEKDAY_APPR_PROCESS_START_1'] 0.0012653325
# ['DAYS_FIRST_DUE_MAX_FIRST_2'] 0.0012635405
# ['CNT_INSTALMENT_FUTURE_MAX_ACTIVE_MEAN'] 0.0012598799
# ['FLAG_DOCUMENT_8'] 0.001256448
# ['CNT_DRAWINGS_POS_CURRENT_MAX'] 0.0012500918
# ['EXP_ENCODED_STATUS_LAST_YEAR_0_MEAN_OVERALL'] 0.0012497285
# ['AMT_CREDIT_GOODS_DIFF_SUM_LAST_5'] 0.0012453787
# ['DAYS_DECISION_MAX_ALL'] 0.0012443459
# ['WEIGHTED_STATUS_FIRST_YEAR_0_MEAN_OVERALL'] 0.0012348138
# ['EXT_SOURCE_3_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0012325515
# ['DAYS_CREDIT_MIN_CREDITACTIVE_CLOSED'] 0.0012318392
# ['WEIGHTED_STATUS_FIRST_MEAN_OVERALL'] 0.0012302889
# ['DAYS_PAYMENT_DIFF_MIN_MIN'] 0.0012302162
# ['WEEKDAY_APPR_PROCESS_START_MIN_LAST_5'] 0.0012293579
# ['AMT_INTEREST_MAX_ALL'] 0.0012257295
# ['DAYS_EMPLOYED'] 0.0012249496
# ['APARTMENTS_SUM_AVG_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0012248392
# ['EXT_SOURCE_1_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.001223368
# ['EXT_SOURCE_1_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.001221985
# ['CREDIT_GOODS_RATIO'] 0.0012200542
# ['EXP_DAYS_PAYMENT_DIFF_LAST_LAST_1_YEAR'] 0.0012182079
# ['PRODUCT_COMBINATION_MEAN_FIRST_2'] 0.0012169349
# ['EXT_SOURCE_3'] 0.0012135542
# ['AMT_DECLINED_MEAN_ALL'] 0.0012120262
# ['EXT_SOURCE_MEAN_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0012114065
# ['AMT_INTEREST_MAX_FIRST_2'] 0.0012077142
# ['DAYS_LAST_PHONE_CHANGE'] 0.0012049394
# ['HOUR_APPR_PROCESS_START_MAX_ALL'] 0.0012030926
# ['CONTRACT_DEMAND_MEAN'] 0.0011986473
# ['SELLERPLACE_AREA_MEAN_ALL'] 0.0011979355
# ['AMT_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS'] 0.0011957528
# ['CREDIT_TYPE_Mortgage_MEAN_OVERALL'] 0.0011932916
# ['DAYS_DECISION_MEAN_FIRST_2'] 0.0011925958
# ['MIN_PAYMENT_RATIO_MEAN_YEAR_0'] 0.0011906499
# ['PAYMENT_MIN_DIFF_MEAN_YEAR_0'] 0.0011897662
# ['INTEREST_DOWNPAYMENT_SUM_ALL'] 0.0011878895
# ['AMT_DECLINED_MEAN_FIRST_2'] 0.0011848074
# ['AMT_PAYMENT_MAX_MEAN'] 0.0011836383
# ['DAYS_PAYMENT_RATIO_MEAN_LAST_1_YEAR'] 0.0011835301
# ['APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2'] 0.0011826317
# ['ANNUITY_GOODS_SUM_FIRST_2'] 0.0011816128
# ['AMT_INCOME_TOTAL_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0011813324
# ['AMT_ANNUITY_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0011806517
# ['DEF_60_CREDIT_RATIO'] 0.0011784328
# ['AMT_DECLINED_MAX_ALL'] 0.0011764604
# ['CNT_PAYMENT_MEAN_LAST_5'] 0.0011723188
# ['DAYS_TERMINATION_MAX_LAST_5'] 0.0011703958
# ['TOTAL_TERM_MEAN_YEAR_REST_MEAN'] 0.0011701518
# ['FLAG_DOCUMENT_11'] 0.0011629723
# ['ANNUITY_INCOME_RATIO_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0011601571
# ['TOTAL_TERM_LAST_MEAN'] 0.0011556773
# ['WEIGHTED_STATUS_FIRST_YEAR_1_MEAN_OVERALL'] 0.0011555603
# ['EXT_SOURCE_1_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.001153866
# ['LANDAREA_AVG'] 0.0011518663
# ['HOUR_PROCESS_CREDIT_MUL'] 0.0011433664
# ['INSTALLMENTS_AMT_PAYMENT_SUM_LAST_1_YEAR_INCOME_RATIO'] 0.0011433617
# ['DAYS_DETAILS_CHANGE_MUL'] 0.0011410326
# ['INTEREST_SHARE_MIN_ALL'] 0.0011400379
# ['AMT_PAYMENT_CURRENT_MEAN'] 0.0011376232
# ['EXT_SOURCE_MEAN_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0011374562
# ['HOUR_APPR_PROCESS_START_MEAN_ALL'] 0.0011361173
# ['CNT_DRAWING_SUM_MAX_YEAR_0'] 0.0011314736
# ['SK_DPD_RATIO_MEAN_ACTIVE_MEAN'] 0.0011293007
# ['BUREAU_DAYS_CREDIT_MAX_CREDITACTIVE_ACTIVE_REGISTRATION_DIFF'] 0.0011289591
# ['APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0011286971
# ['APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2'] 0.0011240974
# ['TOTAL_TERM_MEAN_YEAR_1_MEAN'] 0.0011183245
# ['MIN_PAYMENT_TOTAL_RATIO_MEAN_YEAR_REST'] 0.0011115044
# ['INSTALLMENTS_AMT_PAYMENT_SUM_FIRST_5_INSTALLMENTS_INCOME_RATIO'] 0.0011100937
# ['CNT_INSTALMENT_FUTURE_MEAN_REST_SUM'] 0.0011100441
# ['CNT_PAYMENT_SUM_LAST_5'] 0.0011087368
# ['COMMONAREA_MEDI'] 0.0011080796
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0011056248
# ['CNT_INSTALMENT_MEAN_ACTIVE_MAX'] 0.0011055437
# ['STATUS_MEAN_MAX_CREDITACTIVE_ACTIVE'] 0.0010972557
# ['REGION_RATING_CLIENT_0'] 0.0010971338
# ['GOOD_DOWNPAYMET_RATIO_MAX_FIRST_2'] 0.0010926448
# ['CNT_INSTALMENT_MEAN_REST_SUM'] 0.0010917004
# ['APARTMENTS_SUM_AVG_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0010887804
# ['MONTHS_BALANCE_MEAN_MEAN_OVERALL'] 0.0010847873
# ['DAYS_PAYMENT_RATIO_MAX_LAST_1_YEAR'] 0.001083199
# ['DAYS_PAYMENT_RATIO_MEAN_MEAN'] 0.0010791519
# ['SK_DPD_SUM_ACTIVE_MEAN'] 0.001079022
# ['PAYMENT_MIN_DIFF_MIN'] 0.0010760919
# ['CNT_INSTALMENT_FUTURE_MIN_YEAR_1_MEAN'] 0.001075013
# ['AMT_DOWN_PAYMENT_MEAN_ALL'] 0.0010748917
# ['SELLERPLACE_AREA_MIN_LAST_5'] 0.0010738685
# ['EMPLOYED_TO_AGE_RATIO'] 0.001069897
# ['CONTRACT_SIGNED_MEAN'] 0.0010696772
# ['AMT_BALANCE_MAX'] 0.0010678287
# ['APARTMENTS_SUM_MEDI_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0010677795
# ['AMT_ANNUITY_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0010645614
# ['EXP_MIN_PAYMENT_TOTAL_RATIO_LAST'] 0.0010639881
# ['NAME_GOODS_CATEGORY_MEAN_FIRST_2'] 0.0010624201
# ['DAYS_DECISION_MIN_FIRST_2'] 0.0010612932
# ['EXP_POS_TOTAL_TERM_LAST_YEAR_REST_MEAN'] 0.0010595212
# ['NONLIVINGAPARTMENTS_MODE'] 0.0010570908
# ['CC_EXP_AMT_RECEIVABLE_PRINCIPAL_LAST_INCOME_RATIO'] 0.0010514237
# ['EXT_SOURCE_MEAN_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0010511553
# ['TOTAL_TERM_MAX_YEAR_1_MEAN'] 0.0010489235
# ['PAYMENT_MIN_DIFF_MIN_YEAR_0'] 0.0010480176
# ['AMT_ANNUITY_SUM_CREDITACTIVE_CLOSED'] 0.0010468758
# ['PAYMENT_MIN_DIFF_MEAN_YEAR_REST'] 0.0010463976
# ['DAYS_LAST_DUE_MEAN_LAST_5'] 0.0010454941
# ['AMT_DOWN_PAYMENT_SUM_ALL'] 0.0010431585
# ['LIVE_REGION_NOT_WORK_REGION'] 0.0010395696
# ['HOUSETYPE_MODE_1'] 0.0010383156
# ['HOUR_APPR_PROCESS_START_MEAN_FIRST_2'] 0.0010370789
# ['WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2'] 0.0010319964
# ['EXT_SOURCE_2_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0010298905
# ['AMT_ANNUITY_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0010217474
# ['DAYS_FIRST_DRAWING_MAX_ALL'] 0.0010194482
# ['AMT_CREDIT_SUM_SUM_CREDITACTIVE_ACTIVE'] 0.0010162774
# ['AMT_CREDIT_SUM_SUM_CREDITACTIVE_CLOSED'] 0.0010159814
# ['CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_CLOSED'] 0.001015387
# ['DAYS_FIRST_LAST_DUE_DIFF_MEAN_LAST_5'] 0.0010098065
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_CLOSED'] 0.001005682
# ['YEARS_BEGINEXPLUATATION_MODE'] 0.0010054772
# ['INTEREST_SHARE_MAX_LAST_5'] 0.0009926752
# ['CNT_INSTALMENT_MIN_ACTIVE_MEAN'] 0.0009917849
# ['AMT_PAYMENT_MEAN_FIRST_5_INSTALLMENTS'] 0.0009907931
# ['AMT_INCOME_TOTAL_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0009881532
# ['REGION_RATING_CLIENT_W_CITY_1'] 0.0009868898
# ['INTEREST_SHARE_MAX_FIRST_2'] 0.0009843254
# ['LIVINGAREA_MODE'] 0.0009842563
# ['EXT_SOURCE_MEAN_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.000983557
# ['AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5'] 0.0009743393
# ['INTEREST_RATE_MIN_LAST_5'] 0.00097374484
# ['NAME_CASH_LOAN_PURPOSE_LAST_LAST_5'] 0.0009714085
# ['AMT_CREDIT_SUM_LAST_5'] 0.0009702289
# ['CNT_INSTALMENT_MEAN_COMPLETED_MEAN'] 0.00096942397
# ['AMT_CREDIT_SUM_LIMIT_SUM_CREDITACTIVE_ACTIVE'] 0.0009679907
# ['AMT_INCOME_TOTAL_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0009670821
# ['INTEREST_CREDIT_PRIVILEGED_SUM_LAST_5'] 0.00096539187
# ['DAYS_CREDIT_UPDATE_MEAN_OVERALL'] 0.0009647231
# ['EXP_CNT_INSTALMENT_LAST_MEAN'] 0.0009634985
# ['NONLIVINGAPARTMENTS_MEDI'] 0.0009599829
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_YEAR_1_MEAN'] 0.0009580825
# ['FLOORSMAX_MEDI'] 0.0009572595
# ['EXPECTED_INTEREST'] 0.00095388875
# ['MIN_PAYMENT_RATIO_MIN'] 0.0009502718
# ['AMT_CREDIT_HOUR_PROCESS_START_SUM_LAST_5'] 0.0009490524
# ['YEARS_BEGINEXPLUATATION_AVG'] 0.0009477502
# ['MONTHS_BALANCE_MAX_MEAN'] 0.0009460641
# ['SK_DPD_RATIO_MEAN_YEAR_REST_SUM'] 0.0009455412
# ['EXP_AMT_PAYMENT_RATIO_LAST_FIRST_5_INSTALLMENTS'] 0.0009446104
# ['EXT_SOURCE_3_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0009444969
# ['FLAG_OWN_CAR_0'] 0.00093690294
# ['INCOME_EXT_RATIO'] 0.00093396805
# ['DAYS_LAST_DUE_MEAN_FIRST_2'] 0.0009324577
# ['CNT_INSTALMENT_MAX_YEAR_1_MEAN'] 0.00093090005
# ['EXT_SOURCE_1_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0009302415
# ['AMT_ANNUITY_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0009239236
# ['AMT_INTEREST_MIN_LAST_5'] 0.00092320016
# ['TOTAL_TERM_MEAN_YEAR_REST_SUM'] 0.00091940525
# ['LIVINGAREA_MEDI'] 0.0009165375
# ['SK_DPD_MAX_YEAR_1_MEAN'] 0.00091644883
# ['CNT_INSTALMENT_FUTURE_MEAN_MEAN'] 0.0009163968
# ['APPLICATION_AMT_TO_DECISION_RATIO_MIN_ALL'] 0.00091604836
# ['EXP_BALANCE_LIMIT_RATIO_LAST_ACTIVE'] 0.00091476773
# ['AMT_PAYMENT_RATIO_MAX_MEAN'] 0.00091469946
# ['ANNUITY_INCOME_RATIO_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00091461244
# ['CNT_INSTALMENT_FUTURE_MAX_MEAN'] 0.00090819225
# ['DAYS_DECISION_MAX_LAST_5'] 0.00090751
# ['EXT_SOURCE_1'] 0.00090664375
# ['CREDIT_DURATION_MEAN_OVERALL'] 0.00090033025
# ['CNT_INSTALMENT_MAX_YEAR_REST_MEAN'] 0.0008988184
# ['MIN_PAYMENT_RATIO_MIN_ACTIVE'] 0.0008957238
# ['SK_DPD_RATIO_MEAN_YEAR_0_SUM'] 0.00089562114
# ['EXT_SOURCE_MEAN_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0008938215
# ['EXP_CNT_DRAWING_SUM_LAST'] 0.00088343164
# ['APARTMENTS_SUM_MEDI_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0008832496
# ['DAYS_DETAILS_CHANGE_SUM'] 0.000883028
# ['BUREAU_DAYS_CREDIT_MEAN_OVERALL_REGISTRATION_DIFF'] 0.00088081305
# ['APARTMENTS_SUM_MEDI_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0008807246
# ['INTEREST_CREDIT_PRIVILEGED_SUM_ALL'] 0.00088000286
# ['AMT_APPLICATION_MAX_FIRST_2'] 0.0008789022
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE'] 0.0008774743
# ['APARTMENTS_SUM_MEDI_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0008766454
# ['PRODUCT_COMBINATION_LAST_FIRST_2'] 0.0008764244
# ['AMT_CREDIT_YIELD_GROUP_MEAN_FIRST_2'] 0.0008756226
# ['DAYS_PAYMENT_DIFF_MAX_MEAN'] 0.00087388244
# ['PAYMENT_MIN_DIFF_MEAN_ACTIVE'] 0.00087382534
# ['WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2'] 0.0008730213
# ['AMT_PAYMENT_DIFF_MEAN_MAX'] 0.00087044644
# ['CREDIT_ACTIVE_Sold_MEAN_OVERALL'] 0.0008704455
# ['HOUR_APPR_PROCESS_START_MIN_ALL'] 0.0008701747
# ['EXT_SOURCE_2_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0008688476
# ['WEIGHTED_STATUS_MEAN_YEAR_REST_MEAN_OVERALL'] 0.00086860143
# ['NAME_SELLER_INDUSTRY_LAST_LAST_5'] 0.0008584035
# ['STATUS_MAX_YEAR_0_MEAN_OVERALL'] 0.00085546914
# ['FLAG_OWN_REALTY_0'] 0.0008544971
# ['PRODUCT_COMBINATION_MEAN_LAST_5'] 0.0008524354
# ['CONTRACT_Completed'] 0.0008518498
# ['DAYS_PAYMENT_RATIO_MIN_FIRST_5_INSTALLMENTS'] 0.0008515949
# ['EXP_AMT_PAYMENT_DIFF_LAST_LAST_1_YEAR'] 0.0008513327
# ['APARTMENTS_SUM_AVG_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00085062574
# ['AMT_INSTALMENT_MAX_LAST_1_YEAR'] 0.0008487365
# ['BALANCE_LIMIT_RATIO_MIN'] 0.0008486349
# ['FLAG_DOCUMENT_14'] 0.0008474634
# ['CNT_INSTALMENT_MEAN_ACTIVE_MEAN'] 0.00084646593
# ['APARTMENTS_SUM_MEDI_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00084527984
# ['AMT_ANNUITY_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00084449875
# ['CAR_AGE_DIFF'] 0.0008413777
# ['AMT_CREDIT_GOODS_RATIO_MIN_ALL'] 0.00083466235
# ['AMT_INSTALMENT_SUM_FIRST_5_INSTALLMENTS'] 0.0008326873
# ['EXP_AMT_DRAWING_SUM_LAST_YEAR_1'] 0.00083241344
# ['AMT_ANNUITY_CREDIT_RATIO_MIN_CREDITACTIVE_ACTIVE'] 0.0008320588
# ['BUREAU_DAYS_CREDIT_MAX_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF'] 0.0008251629
# ['ANNUITY_INCOME_RATIO_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00082324346
# ['INTEREST_CREDIT_MEAN_ALL'] 0.00082062936
# ['CODE_GENDER_1'] 0.00082040153
# ['NUM_INSTALMENT_VERSION_SUM_FIRST_5_INSTALLMENTS'] 0.0008188025
# ['OCCUPATION_TYPE_0'] 0.0008182441
# ['HOUR_APPR_PROCESS_START_MEAN_LAST_5'] 0.00080997514
# ['AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2'] 0.0008090816
# ['CURRENT_CREDIT_DEBT_DIFF_MEAN_CREDITACTIVE_ACTIVE'] 0.00080070127
# ['AMT_ENQ_SUM'] 0.0007951445
# ['BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED_REGISTRATION_DIFF'] 0.00079284667
# ['CNT_INSTALMENT_FUTURE_MIN_ACTIVE_MEAN'] 0.00078901765
# ['DAYS_CREDIT_MEANCREDIT_ACTIVE_REST'] 0.0007864124
# ['APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL'] 0.00078430877
# ['MIN_PAYMENT_RATIO_MEAN'] 0.0007824925
# ['PREV_AMT_GOODS_PRICE_MAX_LAST_5_INCOME_RATIO'] 0.0007823676
# ['BALANCE_LIMIT_RATIO_MAX'] 0.0007808588
# ['AGE_EMPLOYED_DIFF_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00078084867
# ['DEF_60_CNT_SOCIAL_CIRCLE'] 0.00077987206
# ['EXP_SK_DPD_RATIO_LAST_YEAR_REST'] 0.0007752095
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0007737524
# ['AMT_CREDIT_SUM_DEBT_MEAN_OVERALL'] 0.0007733798
# ['INTEREST_SHARE_MAX_ALL'] 0.0007699636
# ['LIVINGAREA_AVG'] 0.0007693859
# ['AMT_INCOME_TOTAL_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0007672916
# ['AMT_CREDIT_GOODS_DIFF_SUM_FIRST_2'] 0.0007662576
# ['NAME_PORTFOLIO_MEAN_ALL'] 0.0007651647
# ['AMT_PAYMENT_RATIO_MAX_LAST_1_YEAR'] 0.0007647836
# ['CREDIT_TYPE_Real estate loan_MEAN_OVERALL'] 0.0007622137
# ['EXT_SOURCE_1_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00076055026
# ['EXP_DAYS_PAYMENT_DIFF_LAST_FIRST_5_INSTALLMENTS'] 0.00075959816
# ['SK_DPD_RATIO_MEAN_YEAR_REST_MEAN'] 0.00075908215
# ['CONTRACT_Signed'] 0.00075880653
# ['NUM_INSTALMENT_NUMBER_MAX_SUM'] 0.0007582102
# ['ANNUITY_GOODS_MAX_ALL'] 0.00075801037
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_ALL'] 0.0007570727
# ['PAYMENT_MIN_DIFF_MEAN_YEAR_1'] 0.0007552807
# ['ENQ_CREDIT_RATIO'] 0.0007517901
# ['AMT_CREDIT_YIELD_GROUP_MEAN_ALL'] 0.0007494697
# ['TOTALAREA_MODE'] 0.0007483014
# ['FLAG_DOCUMENT_18'] 0.0007474987
# ['SK_DPD_RATIO_MEAN_YEAR_0_MAX'] 0.0007463368
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_1_MAX'] 0.00074304536
# ['APARTMENTS_SUM_MEDI_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.00074242416
# ['CNT_INSTALMENT_MEAN_REST_MAX'] 0.00074140506
# ['APARTMENTS_SUM_MEDI_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.00073981716
# ['SK_DPD_DEF_MAX_ACTIVE_MEAN'] 0.00073753594
# ['RATE_INTEREST_PRIVILEGED_MEAN_LAST_5'] 0.00073743815
# ['INTEREST_RATE_MAX_LAST_5'] 0.0007372598
# ['AMT_INTEREST_MIN_FIRST_2'] 0.00073715573
# ['FLAG_OWN_CAR_1'] 0.0007355177
# ['STATUS_MEAN_YEAR_REST_MEAN_OVERALL'] 0.0007326548
# ['AMT_INCOME_TOTAL_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0007297001
# ['AMT_INTEREST_RECEIVABLE_MIN_YEAR_0'] 0.00072843314
# ['CNT_INSTALMENT_MEAN_COMPLETED_SUM'] 0.0007240474
# ['AMT_INTEREST_RECEIVABLE_MEAN_ACTIVE'] 0.00071859884
# ['PREV_AMT_ANNUITY_MAX_ALL_INCOME_RATIO'] 0.0007132943
# ['AMT_INSTALMENT_MAX_MEAN'] 0.00071157963
# ['AMT_CREDIT_APPLICATION_RATIO_MIN_LAST_5'] 0.0007073693
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_ACTIVE_INCOME_RATIO'] 0.00070727075
# ['MONTHS_BALANCE_MAX'] 0.0007069204
# ['AMT_PAYMENT_DIFF_MEAN_LAST_1_YEAR'] 0.00070585153
# ['AMT_DOWN_PAYMENT_MAX_ALL'] 0.0007034447
# ['CNT_DRAWING_SUM_SUM_YEAR_0'] 0.00070032035
# ['EXT_SOURCE_3_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00069846946
# ['INTEREST_DOWNPAYMENT_SUM_LAST_5'] 0.00069539854
# ['ANNUITY_GOODS_MEAN_ALL'] 0.00069195474
# ['BASEMENTAREA_MODE'] 0.00069022225
# ['EXP_AMT_INTEREST_RECEIVABLE_LAST_YEAR_1'] 0.0006901968
# ['AMT_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS'] 0.0006885266
# ['AMT_DECLINED_SUM_LAST_5'] 0.00068623386
# ['PAYMENT_MIN_DIFF_MIN_YEAR_REST'] 0.00068474404
# ['AMT_INCOME_TOTAL'] 0.00067990134
# ['EXT_SOURCE_MEAN_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0006792473
# ['AMT_PAYMENT_RATIO_MEAN_MEAN'] 0.0006775066
# ['AMT_ANNUITY_CREDIT_RATIO_MEAN_CREDITACTIVE_CLOSED'] 0.00067565055
# ['EXT_SOURCE_2_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0006736685
# ['DAYS_FIRST_DUE_MEAN_LAST_5'] 0.00067366834
# ['PREV_AMT_GOODS_PRICE_MEAN_ALL_INCOME_RATIO'] 0.0006714872
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_YEAR_0_MEAN'] 0.0006702194
# ['AMT_CREDIT_GOODS_RATIO_MIN_LAST_5'] 0.00066578103
# ['SK_DPD_RATIO_MAX_YEAR_REST_MEAN'] 0.00066341646
# ['SK_DPD_RATIO_MAX_YEAR_1_MEAN'] 0.0006633583
# ['EXP_AMT_PAYMENT_DIFF_LAST_FIRST_5_INSTALLMENTS'] 0.0006632381
# ['NAME_YIELD_GROUP_LAST_LAST_5'] 0.00066019705
# ['CNT_INSTALMENT_FUTURE_MEAN_MAX'] 0.000656948
# ['REG_REGION_NOT_WORK_REGION'] 0.0006567185
# ['CREDIT_DOWNPAYMENT_RATIO_MAX_LAST_5'] 0.0006543892
# ['AMT_ANNUITY_MEAN_FIRST_2'] 0.0006532844
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_MEAN'] 0.00065077934
# ['ANNUITY_INCOME_RATIO_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00064884307
# ['SELLERPLACE_AREA_MAX_ALL'] 0.00064767187
# ['EXT_SOURCE_1_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0006431163
# ['ANNUITY_SUM_LAST_5'] 0.00063908345
# ['EXT_SOURCE_MEAN_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00063147093
# ['NFLAG_LAST_APPL_IN_DAY_SUM_ALL'] 0.0006310758
# ['INTEREST_DOWNPAYMENT_MEAN_FIRST_2'] 0.00063089764
# ['CREDIT_EXT_RATIO'] 0.00062761887
# ['CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL'] 0.00062213483
# ['INTEREST_DOWNPAYMENT_MAX_FIRST_2'] 0.00062118843
# ['CNT_DRAWINGS_CURRENT_SUM'] 0.00061583135
# ['AMT_ANNUITY_MEAN_LAST_5'] 0.0006120548
# ['ANNUITY_SUM_FIRST_2'] 0.0006087809
# ['AMT_PAYMENT_SUM_SUM'] 0.0006071836
# ['EXT_SOURCE_MEAN_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.00060467335
# ['NAME_CONTRACT_STATUS_MEAN_ALL'] 0.0005993902
# ['AMT_PAYMENT_RATIO_MEAN_MAX'] 0.0005943644
# ['ANNUITY_INCOME_RATIO_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00059422414
# ['AGE_EMPLOYED_DIFF_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0005937345
# ['CNT_INSTALMENT_MEAN_YEAR_1_SUM'] 0.00059222337
# ['AMT_DRAWINGS_POS_CURRENT_SUM'] 0.0005904285
# ['WEIGHTED_STATUS_MAX_YEAR_1_MEAN_OVERALL'] 0.0005891841
# ['AMT_INTEREST_RECEIVABLE_MEAN'] 0.000586882
# ['FLOORSMAX_AVG'] 0.00058529584
# ['PREV_AMT_GOODS_PRICE_SUM_LAST_5_INCOME_RATIO'] 0.00057822285
# ['EXP_POS_TOTAL_TERM_MEAN_SUM'] 0.0005746483
# ['EXT_SOURCE_3_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00057347445
# ['EXP_AMT_RECEIVABLE_PRINCIPAL_LAST'] 0.00057131494
# ['AMT_ANNUITY_MEAN_CREDITACTIVE_ACTIVE'] 0.00056733494
# ['CREDIT_TYPE_Consumer credit_MEAN_OVERALL'] 0.0005653663
# ['INSTALLMENTS_AMT_PAYMENT_SUM_MAX_INCOME_RATIO'] 0.0005652049
# ['AMT_RECEIVABLE_PRINCIPAL_MEAN'] 0.00055877236
# ['AMT_CREDIT_YIELD_GROUP_MIN_LAST_5'] 0.0005584891
# ['CNT_DRAWING_SUM_SUM_YEAR_1'] 0.0005566179
# ['AGE_EMPLOYED_DIFF'] 0.00055611506
# ['AMT_CREDIT_GOODS_DIFF_MIN_ALL'] 0.0005549585
# ['BUREAU_DAYS_CREDIT_MAX_CREDITACTIVE_CLOSED_REGISTRATION_DIFF'] 0.00055472716
# ['MIN_PAYMENT_RATIO_MEAN_YEAR_1'] 0.0005536214
# ['AMT_PAYMENT_TOTAL_CURRENT_MEAN'] 0.00055276736
# ['CNT_INSTALMENT_FUTURE_MEAN_SUM'] 0.00055095484
# ['EXT_SOURCE_3_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0005500623
# ['AMT_INSTALMENT_MAX_FIRST_5_INSTALLMENTS'] 0.0005500381
# ['EXP_PAYMENT_MIN_DIFF_LAST_YEAR_1'] 0.0005471214
# ['AMT_ANNUITY_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0005464647
# ['EXT_SOURCE_MEAN_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00054110104
# ['LIVE_CITY_NOT_WORK_CITY'] 0.0005381379
# ['DAYS_PAYMENT_RATIO_MIN_LAST_1_YEAR'] 0.0005333115
# ['AMT_ANNUITY_MAX_CREDITACTIVE_CLOSED'] 0.0005308422
# ['AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2'] 0.0005300486
# ['NAME_TYPE_SUITE_MEAN_FIRST_2'] 0.00052884413
# ['APARTMENTS_SUM_MEDI_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00052713195
# ['AMT_CREDIT_MAX_ALL'] 0.00052396505
# ['AMT_CREDIT_YIELD_GROUP_SUM_ALL'] 0.0005199584
# ['DAYS_PAYMENT_RATIO_MIN_MIN'] 0.00051466195
# ['BUREAU_DAYS_CREDIT_MAX_CREDITACTIVE_CLOSED_EMPLOYED_DIFF'] 0.0005139821
# ['AMT_RECEIVABLE_PRINCIPAL_MAX'] 0.00051356363
# ['NAME_PORTFOLIO_MEAN_LAST_5'] 0.0005121706
# ['PREV_AMT_GOODS_PRICE_MEAN_FIRST_2_INCOME_RATIO'] 0.00050543033
# ['DAYS_TERMINATION_MAX_ALL'] 0.0005035518
# ['LIVINGAPARTMENTS_MEDI'] 0.00050226704
# ['AMT_INCOME_TOTAL_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0005016732
# ['DAYS_TERMINATION_MEAN_LAST_5'] 0.00050001364
# ['FLAG_OWN_REALTY_1'] 0.0004981321
# ['APARTMENTS_SUM_MEDI_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00049792585
# ['CREDIT_ACTIVE_Active_MEAN_OVERALL'] 0.00049746863
# ['AMT_ANNUITY_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.000497316
# ['AMT_CREDIT_GOODS_DIFF_MEAN_ALL'] 0.00049529976
# ['AMT_DOWN_PAYMENT_MAX_FIRST_2'] 0.000493073
# ['EXT_SOURCE_1_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00049234263
# ['DAYS_CREDIT_LAST_CREDITACTIVE_ACTIVE'] 0.0004910434
# ['AMT_CREDIT_GOODS_DIFF_MAX_ALL'] 0.00049006223
# ['CC_EXP_AMT_RECIVABLE_LAST_INCOME_RATIO'] 0.00048922247
# ['CREDIT_DOWNPAYMENT_RATIO_MAX_FIRST_2'] 0.00048569246
# ['AMT_REQ_CREDIT_BUREAU_MON'] 0.00048392324
# ['AMT_CREDIT_MEAN_ALL'] 0.00048387257
# ['SK_DPD_RATIO_MAX_ACTIVE_MEAN'] 0.00047618037
# ['ORGANIZATION_TYPE_0'] 0.00047062
# ['BUREAU_DAYS_CREDIT_LAST_CREDITACTIVE_CLOSED_EMPLOYED_DIFF'] 0.00046765484
# ['EXP_MIN_PAYMENT_TOTAL_RATIO_LAST_YEAR_1'] 0.00046696785
# ['RATE_DOWN_PAYMENT_MAX_ALL'] 0.000464138
# ['PREV_AMT_GOODS_PRICE_SUM_ALL_INCOME_RATIO'] 0.00046225585
# ['AMT_INSTALMENT_MEAN_FIRST_5_INSTALLMENTS'] 0.00046145986
# ['AMT_CREDIT_MEAN_FIRST_2'] 0.00045812986
# ['EXP_AMT_CREDIT_LIMIT_ACTUAL_LAST'] 0.00045744466
# ['SK_DPD_RATIO_MEAN_SUM'] 0.00045648348
# ['AMT_DRAWINGS_ATM_CURRENT_MAX'] 0.00045561977
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_REST_SUM'] 0.00045393922
# ['GOOD_DOWNPAYMET_RATIO_MEAN_LAST_5'] 0.00045362496
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0004491463
# ['AMT_ANNUITY_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.000447179
# ['WEIGHTED_STATUS_MEAN_YEAR_0_MEAN_OVERALL'] 0.00044627205
# ['EXT_SOURCE_2_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.00044481177
# ['EXT_SOURCE_3_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00044405393
# ['EXP_AMT_PAYMENT_RATIO_LAST_MEAN'] 0.00044347814
# ['WEIGHTED_STATUS_SUM_MEAN_OVERALL'] 0.0004410747
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_SUMCREDIT_ACTIVE_REST_INCOME_RATIO'] 0.00044106602
# ['EXP_AMT_DRAWING_SUM_LAST_ACTIVE'] 0.0004388139
# ['EXT_SOURCE_MEAN_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0004342716
# ['LANDAREA_MODE'] 0.00043122258
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL'] 0.0004292391
# ['EXP_POS_TOTAL_TERM_LAST_COMPLETED_MEAN'] 0.0004277813
# ['AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_ACTIVE'] 0.0004200466
# ['CODE_GENDER_0'] 0.0004173432
# ['NAME_SELLER_INDUSTRY_MEAN_ALL'] 0.0004164206
# ['YEARS_BUILD_MEDI'] 0.0004097626
# ['FLAG_LAST_APPL_PER_CONTRACT_MEAN_ALL'] 0.00040918746
# ['AMT_INSTALMENT_MEAN_LAST_1_YEAR'] 0.00040765424
# ['CNT_INSTALMENT_MATURE_CUM_SUM'] 0.00040219037
# ['AMT_ANNUITY_MEANCREDIT_ACTIVE_REST'] 0.0003982957
# ['AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_ACTIVE'] 0.0003978898
# ['EXP_AMT_DRAWING_SUM_LAST_COMPLETED'] 0.0003938626
# ['AMT_INSTALMENT_SUM_LAST_1_YEAR'] 0.0003905221
# ['APARTMENTS_SUM_AVG_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00038255547
# ['WEIGHTED_STATUS_LAST_YEAR_1_MEAN_OVERALL'] 0.00038069402
# ['CNT_INSTALMENT_FUTURE_MEAN_ACTIVE_SUM'] 0.00037745875
# ['ENTRANCES_MODE'] 0.00037621267
# ['AMT_PAYMENT_MEAN_MEAN'] 0.0003730458
# ['CREDIT_TYPE_Another type of loan_MEAN_OVERALL'] 0.0003729199
# ['AMT_ANNUITY_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0003719269
# ['AMT_GOODS_PRICE_MAX_LAST_5'] 0.00036949335
# ['ANNUITY_GOODS_MEAN_LAST_5'] 0.0003641136
# ['ANNUITY_INCOME_RATIO_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00036253696
# ['EXT_SOURCE_MEAN_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00036211606
# ['NAME_PRODUCT_TYPE_LAST_LAST_5'] 0.0003530655
# ['CNT_INSTALMENT_MEAN_SUM'] 0.00035033966
# ['EXP_DAYS_PAYMENT_RATIO_LAST_LAST_1_YEAR'] 0.00035026218
# ['EXT_SOURCE_3_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.00034028993
# ['AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_CLOSED'] 0.00033907077
# ['INSTALLMENTS_AMT_PAYMENT_SUM_SUM_INCOME_RATIO'] 0.00033787964
# ['OCCUPATION_TYPE_1'] 0.00033103314
# ['BALANCE_LIMIT_RATIO_MEAN_YEAR_1'] 0.000330052
# ['NAME_CLIENT_TYPE_LAST_FIRST_2'] 0.00032823402
# ['AMT_CREDIT_GOODS_RATIO_MAX_FIRST_2'] 0.000327264
# ['FLAG_OVERDUE_RECENT_MEAN_OVERALL'] 0.00032465634
# ['AMT_INCOME_TOTAL_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00032453105
# ['REGION_RATING_MAX'] 0.00032418838
# ['COMMONAREA_MODE'] 0.0003231485
# ['INSTALLMENTS_AMT_PAYMENT_MEAN_FIRST_5_INSTALLMENTS_INCOME_RATIO'] 0.00032174194
# ['ELEVATORS_MODE'] 0.00031852978
# ['REG_CITY_NOT_LIVE_CITY'] 0.00031426025
# ['STATUS_MAX_YEAR_REST_MEAN_OVERALL'] 0.00031007515
# ['AMT_PAYMENT_DIFF_MIN_MEAN'] 0.00030499726
# ['AMT_ANNUITY_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.00030080954
# ['GOOD_DOWNPAYMET_RATIO_MAX_ALL'] 0.0002993044
# ['CNT_INSTALMENT_MIN_YEAR_REST_MEAN'] 0.00029592338
# ['EXP_POS_TOTAL_TERM_LAST_YEAR_1_MEAN'] 0.00028743368
# ['CNT_PAYMENT_MEAN_FIRST_2'] 0.00028727134
# ['APARTMENTS_SUM_AVG_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00028448005
# ['STATUS_FIRST_YEAR_0_MEAN_OVERALL'] 0.00028399398
# ['EXT_SOURCE_MAX'] 0.00028333705
# ['AMT_INTEREST_MEAN_FIRST_2'] 0.00028023132
# ['FLAG_DOCUMENT_21'] 0.0002794938
# ['RATE_DOWN_PAYMENT_MAX_FIRST_2'] 0.00027846536
# ['PREV_AMT_GOODS_PRICE_MEAN_LAST_5_INCOME_RATIO'] 0.00027362394
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_REST_MEAN'] 0.00027270018
# ['CNT_PAYMENT_SUM_FIRST_2'] 0.00027162835
# ['AMT_REQ_CREDIT_BUREAU_DAY'] 0.00027002423
# ['ANNUITY_INCOME_RATIO_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00026595173
# ['EXT_SOURCE_2_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0002631689
# ['DAYS_REGISTRATION'] 0.00026291292
# ['AMT_REQ_CREDIT_BUREAU_QRT'] 0.00026250418
# ['MIN_PAYMENT_RATIO_MEAN_ACTIVE'] 0.0002569671
# ['INCOME_APARTMENT_AVG_MUL'] 0.00025402103
# ['INTEREST_RATE_MAX_FIRST_2'] 0.00025158862
# ['NAME_TYPE_SUITE_LAST_FIRST_2'] 0.00024412281
# ['AMT_PAYMENT_DIFF_MIN_LAST_1_YEAR'] 0.00023709815
# ['CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL'] 0.00023707926
# ['AMT_RECIVABLE_MAX'] 0.0002341764
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_MAXCREDIT_ACTIVE_REST_INCOME_RATIO'] 0.00023199694
# ['PREV_AMT_ANNUITY_MAX_FIRST_2_INCOME_RATIO'] 0.00022727183
# ['MIN_PAYMENT_RATIO_MEAN_YEAR_REST'] 0.0002232891
# ['DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE'] 0.00021552789
# ['NAME_GOODS_CATEGORY_MEAN_ALL'] 0.00021445703
# ['CREDIT_GOODS_DIFF'] 0.00021146322
# ['CNT_INSTALMENT_MAX_YEAR_0_MEAN'] 0.00020286671
# ['CNT_DRAWINGS_ATM_CURRENT_MAX'] 0.00019966842
# ['SUM_FLAGS_DOCUMENTS'] 0.00019134053
# ['SK_DPD_DEF_SUM_YEAR_1'] 0.00018421242
# ['GOODS_INCOME_RATIO'] 0.00018304036
# ['EXP_SK_DPD_RATIO_LAST_COMPLETED'] 0.0001716988
# ['AMT_INCOME_TOTAL_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.00016500679
# ['AMT_ANNUITY_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00016399508
# ['NAME_YIELD_GROUP_LAST_FIRST_2'] 0.00016231457
# ['NAME_GOODS_CATEGORY_LAST_FIRST_2'] 0.00016024793
# ['AMT_APPLICATION_MAX_ALL'] 0.00015777664
# ['HOUR_APPR_PROCESS_START_MAX_LAST_5'] 0.00015666519
# ['APARTMENTS_SUM_AVG_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0001553307
# ['AMT_REQ_CREDIT_BUREAU_HOUR'] 0.00015521239
# ['PAYMENT_MIN_DIFF_MIN_ACTIVE'] 0.000154294
# ['SK_DPD_RATIO_MAX_MEAN'] 0.00015032488
# ['APARTMENTS_SUM_MEDI_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.00014647905
# ['AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL'] 0.00013976275
# ['FLAG_LAST_APPL_PER_CONTRACT_SUM_ALL'] 0.00013152751
# ['AMT_REQ_CREDIT_BUREAU_YEAR'] 0.00013100398
# ['NAME_PAYMENT_TYPE_LAST_LAST_5'] 0.00012406032
# ['AMT_ANNUITY_CREDIT_RATIO_MAX_CREDITACTIVE_CLOSED'] 0.0001164668
# ['CNT_INSTALMENT_FUTURE_MEAN_ACTIVE_MEAN'] 0.00010072846
# ['APARTMENTS_SUM_MODE'] 7.992104e-05
# ['EXP_MIN_PAYMENT_RATIO_LAST'] 7.948522e-05
# ['WEIGHTED_STATUS_MEAN_MEAN_OVERALL'] 6.912862e-05
# ['DAYS_PAYMENT_RATIO_MEAN_MAX'] 6.879966e-05
# ['BALANCE_LIMIT_RATIO_MAX_YEAR_REST'] 6.109356e-05
# ['AMT_INTEREST_MEAN_LAST_5'] 5.255552e-05
# ['HOUR_APPR_PROCESS_START_MAX_FIRST_2'] 4.377411e-05
# ['CREDIT_DOWNPAYMENT_RATIO_MEAN_LAST_5'] 1.5738344e-05
# ['EXP_AMT_INTEREST_RECEIVABLE_LAST'] 0.0
# ['CNT_INSTALMENT_MEAN_MAX'] 0.0
# ['EXP_POS_TOTAL_TERM_MEAN_MAX'] 0.0
# ['AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL'] 0.0
# ['AMT_ANNUITY_SUM_CREDITACTIVE_ACTIVE'] 0.0
# ['AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL'] 0.0
# ['CC_AMT_RECEIVABLE_PRINCIPAL_MAX_INCOME_RATIO'] 0.0
# ['AMT_INCOME_TOTAL_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0
# ['DAYS_PAYMENT_DIFF_MEAN_MAX'] 0.0
# ['AMT_ANNUITY_MEAN_ALL'] 0.0
# ['AMT_GOODS_PRICE_MEAN_LAST_5'] 0.0
# ['WEIGHTED_STATUS_MEAN_YEAR_1_MEAN_OVERALL'] 0.0
# ['CNT_FAM_MEMBERS'] 0.0
# ['AMT_APPLICATION_SUM_LAST_5'] 0.0
# ['CREDIT_ACTIVE_Bad debt_MEAN_OVERALL'] 0.0
# ['AMT_CREDIT_MAX_LAST_5'] 0.0
# ['NAME_PAYMENT_TYPE_MEAN_ALL'] 0.0
# ['INTEREST_RATE_MEAN_ALL'] 0.0
# ['EXP_MIN_PAYMENT_RATIO_LAST_YEAR_1'] 0.0
# ['CNT_INSTALMENT_MEAN_YEAR_0_MEAN'] 0.0
# ['AMT_CREDIT_LIMIT_ACTUAL_MEAN'] 0.0
# ['SK_DPD_RATIO_MEAN_YEAR_1_MAX'] 0.0
# ['OBS_DEF_60_MUL'] 0.0
# ['AMT_ANNUITY'] 0.0
# ['DAYS_ENDDATE_FACT_MEAN_OVERALL'] 0.0
# ['AMT_CREDIT_GOODS_DIFF_MIN_LAST_5'] 0.0
# ['CNT_CREDIT_PROLONG_MEAN_OVERALL'] 0.0
# ['AMT_APPLICATION_MEAN_ALL'] 0.0
# ['INTEREST_CREDIT_SUM_LAST_5'] 0.0
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_MEAN'] 0.0
# ['AMT_CREDIT_GOODS_RATIO_MAX_LAST_5'] 0.0
# ['AMT_CREDIT_SUM_FIRST_2'] 0.0
# ['DEF_30_CREDIT_RATIO'] 0.0
# ['MONTHS_BALANCE_MAX_MEAN_OVERALL'] 0.0
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0
# ['CNT_INSTALMENT_FUTURE_MAX_YEAR_1_MEAN'] 0.0
# ['NAME_CONTRACT_STATUS_MAX_LAST_5'] 0.0
# ['TOTAL_TERM_MEAN_REST_MEAN'] 0.0
# ['ANNUITY_GOODS_MAX_LAST_5'] 0.0
# ['AMT_PAYMENT_MEAN_SUM'] 0.0
# ['AMT_PAYMENT_DIFF_MEAN_FIRST_5_INSTALLMENTS'] 0.0
# ['EXP_MIN_PAYMENT_RATIO_LAST_ACTIVE'] 0.0
# ['AMT_PAYMENT_SUM_FIRST_5_INSTALLMENTS'] 0.0
# ['DAYS_FIRST_LAST_DUE_DIFF_MAX_FIRST_2'] 0.0
# ['AMT_CREDIT_GOODS_RATIO_MEAN_LAST_5'] 0.0
# ['EMERGENCYSTATE_MODE_0'] 0.0
# ['CURRENT_CREDIT_DEBT_DIFF_MEAN_CREDITACTIVE_CLOSED'] 0.0
# ['REGION_RATING_MUL_1'] 0.0
# ['ELEVATORS_AVG'] 0.0
# ['AMT_ANNUITY_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2'] 0.0
# ['AMT_PAYMENT_RATIO_MIN_LAST_1_YEAR'] 0.0
# ['INTEREST_RATE_MIN_ALL'] 0.0
# ['DAYS_CREDIT_LAST_CREDITACTIVE_CLOSED'] 0.0
# ['AMT_DRAWINGS_POS_CURRENT_MAX'] 0.0
# ['ANNUITY_MAX_FIRST_2'] 0.0
# ['DAYS_PAYMENT_DIFF_MIN_MEAN'] 0.0
# ['AMT_INCOME_TOTAL_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['CNT_INSTALMENT_FUTURE_MIN_YEAR_REST_MEAN'] 0.0
# ['EXP_AMT_BALANCE_LAST'] 0.0
# ['STATUS_MEAN_MEAN_OVERALL'] 0.0
# ['NONLIVINGAREA_MODE'] 0.0
# ['FLOORSMIN_AVG'] 0.0
# ['BALANCE_LIMIT_RATIO_MAX_ACTIVE'] 0.0
# ['EXP_WEIGHTED_STATUS_LAST_YEAR_REST_MEAN_OVERALL'] 0.0
# ['CNT_INSTALMENT_MEAN_YEAR_REST_SUM'] 0.0
# ['CURRENCY_currency 3_MEAN_OVERALL'] 0.0
# ['MIN_PAYMENT_TOTAL_RATIO_MEAN_YEAR_1'] 0.0
# ['WEEKDAY_APPR_PROCESS_START_MEAN_ALL'] 0.0
# ['SK_DPD_DEF_SUM_YEAR_REST_MEAN'] 0.0
# ['INTEREST_CREDIT_MAX_ALL'] 0.0
# ['PREV_AMT_ANNUITY_SUM_ALL_INCOME_RATIO'] 0.0
# ['AMT_APPLICATION_MEAN_LAST_5'] 0.0
# ['NAME_TYPE_SUITE_0'] 0.0
# ['CURRENCY_currency 4_MEAN_OVERALL'] 0.0
# ['BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE_REGISTRATION_DIFF'] 0.0
# ['EXP_CNT_INSTALMENT_LAST_COMPLETED_MEAN'] 0.0
# ['OBS_30_CNT_SOCIAL_CIRCLE'] 0.0
# ['STATUS_LAST_YEAR_1_MEAN_OVERALL'] 0.0
# ['AGE_EMPLOYED_DIFF_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['CNT_PAYMENT_MEAN_ALL'] 0.0
# ['DAYS_DECISION_MIN_LAST_5'] 0.0
# ['CNT_INSTALMENT_MIN_MEAN'] 0.0
# ['CC_AMT_RECIVABLE_MAX_INCOME_RATIO'] 0.0
# ['SK_DPD_RATIO_MAX_YEAR_0_MEAN'] 0.0
# ['STATUS_MEAN_YEAR_1_MEAN_OVERALL'] 0.0
# ['EXP_POS_TOTAL_TERM_LAST_ACTIVE_MEAN'] 0.0
# ['ANNUITY_GOODS_MEAN_FIRST_2'] 0.0
# ['EXT_SOURCE_MEAN_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['AGE_EMPLOYED_DIFF_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['SK_DPD_DEF_MAX_YEAR_1_MEAN'] 0.0
# ['WEIGHTED_STATUS_MEAN_MEAN_CREDITACTIVE_CLOSED'] 0.0
# ['REG_REGION_NOT_LIVE_REGION'] 0.0
# ['ANNUITY_INCOME_RATIO_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_MAX'] 0.0
# ['CODE_REJECT_REASON_LAST_LAST_5'] 0.0
# ['YEARS_BUILD_AVG'] 0.0
# ['INTEREST_DOWNPAYMENT_SUM_FIRST_2'] 0.0
# ['AMT_ANNUITY_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['EXPECTED_CNT_PAYMENT'] 0.0
# ['AMT_INTEREST_RECEIVABLE_MIN_REST'] 0.0
# ['SELLERPLACE_AREA_MAX_FIRST_2'] 0.0
# ['WEEKDAY_APPR_PROCESS_START_MAX_ALL'] 0.0
# ['SELLERPLACE_AREA_MEAN_FIRST_2'] 0.0
# ['AMT_CREDIT_SUM_ALL'] 0.0
# ['APARTMENTS_SUM_MEDI_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['NONLIVINGAREA_AVG'] 0.0
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5'] 0.0
# ['STATUS_MAX_YEAR_1_MEAN_OVERALL'] 0.0
# ['ANNUITY_MEAN_FIRST_2'] 0.0
# ['DAYS_FIRST_DUE_MEAN_ALL'] 0.0
# ['AMT_PAYMENT_SUM_LAST_1_YEAR'] 0.0
# ['CREDIT_DAY_OVERDUE_MEAN_OVERALL'] 0.0
# ['AMT_CREDIT_MEAN_LAST_5'] 0.0
# ['EXP_AMT_DRAWING_SUM_LAST_YEAR_REST'] 0.0
# ['INTEREST_RATE_MEAN_LAST_5'] 0.0
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['INTEREST_DOWNPAYMENT_MEAN_ALL'] 0.0
# ['AMT_REQ_CREDIT_BUREAU_WEEK'] 0.0
# ['FLAG_DOCUMENT_9'] 0.0
# ['NAME_FAMILY_STATUS_1'] 0.0
# ['PREV_AMT_ANNUITY_SUM_FIRST_2_INCOME_RATIO'] 0.0
# ['AMT_INSTALMENT_SUM_SUM'] 0.0
# ['DAYS_PAYMENT_DIFF_MIN_LAST_1_YEAR'] 0.0
# ['NAME_TYPE_SUITE_LAST_LAST_5'] 0.0
# ['PAYMENT_MIN_DIFF_MEAN'] 0.0
# ['DAYS_DECISION_MIN_ALL'] 0.0
# ['INTEREST_SHARE_MEAN_LAST_5'] 0.0
# ['EXT_SOURCE_1_MAX_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['BUREAU_DAYS_CREDIT_MIN_CREDITACTIVE_ACTIVE_REGISTRATION_DIFF'] 0.0
# ['AMT_PAYMENT_MEAN_MAX'] 0.0
# ['MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2'] 0.0
# ['AMT_DOWN_PAYMENT_SUM_FIRST_2'] 0.0
# ['DAYS_PAYMENT_RATIO_MAX_FIRST_5_INSTALLMENTS'] 0.0
# ['CNT_DRAWING_SUM_SUM_YEAR_REST'] 0.0
# ['DAYS_FIRST_DRAWING_MEAN_LAST_5'] 0.0
# ['SK_DPD_RATIO_MEAN_YEAR_0_MEAN'] 0.0
# ['CONTRACT_APPROVED_MEAN'] 0.0
# ['CNT_INSTALMENT_MATURE_CUM_MAX'] 0.0
# ['APARTMENTS_SUM_AVG_MIN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['EXP_ENCODED_STATUS_LAST_YEAR_1_MEAN_OVERALL'] 0.0
# ['NAME_GOODS_CATEGORY_LAST_LAST_5'] 0.0
# ['SK_DPD_DEF_MAX_MEAN'] 0.0
# ['AMT_INSTALMENT_MEAN_SUM'] 0.0
# ['DAYS_FIRST_DUE_MAX_ALL'] 0.0
# ['AMT_CREDIT_HOUR_PROCESS_START_MEAN_LAST_5'] 0.0
# ['BUREAU_DAYS_CREDIT_LAST_CREDITACTIVE_CLOSED_REGISTRATION_DIFF'] 0.0
# ['NAME_TYPE_SUITE_MEAN_LAST_5'] 0.0
# ['EXP_AMT_INTEREST_RECEIVABLE_LAST_YEAR_REST'] 0.0
# ['CURRENT_CREDIT_DEBT_DIFF_MIN_CREDITACTIVE_ACTIVE'] 0.0
# ['NAME_YIELD_GROUP_MEAN_ALL'] 0.0
# ['EXP_CNT_INSTALMENT_LAST_YEAR_1_MEAN'] 0.0
# ['EXT_SOURCE_3_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['INTEREST_CREDIT_MEAN_FIRST_2'] 0.0
# ['REGION_RATING_MEAN_0'] 0.0
# ['EXT_SOURCE_2'] 0.0
# ['AMT_CREDIT_SUM_LIMIT_MAX_CREDITACTIVE_CLOSED'] 0.0
# ['DAYS_DECISION_MEAN_ALL'] 0.0
# ['STATUS_MEAN_MAX_CREDITACTIVE_CLOSED'] 0.0
# ['NAME_CONTRACT_STATUS_MEAN_LAST_5'] 0.0
# ['FLAG_REGIONS'] 0.0
# ['EXT_SOURCE_1_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['TOTAL_TERM_MAX_MEAN'] 0.0
# ['DAYS_FIRST_LAST_DUE_DIFF_MEAN_ALL'] 0.0
# ['SK_DPD_RATIO_MEAN_YEAR_REST_MAX'] 0.0
# ['NAME_FAMILY_STATUS_0'] 0.0
# ['NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5'] 0.0
# ['CNT_INSTALMENT_MEAN_YEAR_REST_MEAN'] 0.0
# ['CREDIT_ACTIVE_Closed_MEAN_OVERALL'] 0.0
# ['NAME_CASH_LOAN_PURPOSE_MEAN_FIRST_2'] 0.0
# ['NAME_PAYMENT_TYPE_MEAN_LAST_5'] 0.0
# ['SELLERPLACE_AREA_MAX_LAST_5'] 0.0
# ['AMT_INSTALMENT_MEAN_MEAN'] 0.0
# ['EXP_CNT_INSTALMENT_LAST_YEAR_REST_MEAN'] 0.0
# ['EXP_WEIGHTED_STATUS_LAST_YEAR_0_MEAN_OVERALL'] 0.0
# ['SK_DPD_DEF_MAX_YEAR_REST_MEAN'] 0.0
# ['INCOME_ANNUITY_DIFF'] 0.0
# ['EXP_WEIGHTED_STATUS_LAST_MEAN_OVERALL'] 0.0
# ['NAME_CONTRACT_TYPE_MEAN_ALL'] 0.0
# ['AMT_PAYMENT_MEAN_LAST_1_YEAR'] 0.0
# ['SK_DPD_RATIO_MEAN_ACTIVE_SUM'] 0.0
# ['CNT_CHILDREN'] 0.0
# ['AMT_PAYMENT_CURRENT_MAX'] 0.0
# ['DAYS_CREDIT_MAX_CREDITACTIVE_CLOSED'] 0.0
# ['OBS_DEF_30_MUL'] 0.0
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['BUREAU_DAYS_CREDIT_MEAN_OVERALL_EMPLOYED_DIFF'] 0.0
# ['AMT_DECLINED_MAX_FIRST_2'] 0.0
# ['CURRENT_DEBT_TO_CREDIT_RATIO_MINCREDIT_ACTIVE_REST'] 0.0
# ['CODE_REJECT_REASON_MEAN_LAST_5'] 0.0
# ['DAYS_PAYMENT_DIFF_MEAN_MIN'] 0.0
# ['INTEREST_SHARE_MEAN_FIRST_2'] 0.0
# ['AMT_PAYMENT_MAX_LAST_1_YEAR'] 0.0
# ['DAYS_FIRST_DRAWING_MAX_LAST_5'] 0.0
# ['AMT_INCOME_TOTAL_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0
# ['CC_AMT_RECEIVABLE_PRINCIPAL_MEAN_INCOME_RATIO'] 0.0
# ['AMT_ANNUITY_CREDIT_RATIO_MIN_CREDITACTIVE_CLOSED'] 0.0
# ['INTEREST_DOWNPAYMENT_MAX_ALL'] 0.0
# ['DEF_30_60_SUM'] 0.0
# ['FLAG_DOCUMENT_13'] 0.0
# ['AMT_PAYMENT_RATIO_MAX_FIRST_5_INSTALLMENTS'] 0.0
# ['APARTMENTS_MODE'] 0.0
# ['AMT_APPLICATION_SUM_ALL'] 0.0
# ['AMT_APPLICATION_MAX_LAST_5'] 0.0
# ['APARTMENTS_SUM_AVG_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['CNT_INSTALMENT_MIN_YEAR_1_MEAN'] 0.0
# ['CNT_DRAWING_SUM_SUM'] 0.0
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX_CREDITACTIVE_CLOSED_INCOME_RATIO'] 0.0
# ['APARTMENTS_SUM_AVG_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['CHANNEL_TYPE_MEAN_FIRST_2'] 0.0
# ['BUREAU_DAYS_CREDIT_MEANCREDIT_ACTIVE_REST_EMPLOYED_DIFF'] 0.0
# ['EXT_SOURCE_MIN'] 0.0
# ['CHILDREN_INCOME_RATIO'] 0.0
# ['CONTRACT_ACTIVE_MEAN'] 0.0
# ['MISSING_VALS_TOTAL_CC_SUM'] 0.0
# ['BUREAU_AMT_ANNUITY_MEAN_OVERALL_INCOME_RATIO'] 0.0
# ['FLOORSMIN_MODE'] 0.0
# ['CREDIT_INCOME_RATIO'] 0.0
# ['STATUS_FIRST_YEAR_REST_MEAN_OVERALL'] 0.0
# ['PREV_AMT_ANNUITY_MAX_LAST_5_INCOME_RATIO'] 0.0
# ['BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN_OVERALL_INCOME_RATIO'] 0.0
# ['CNT_INSTALMENT_MEAN_ACTIVE_SUM'] 0.0
# ['INCOME_APARTMENT_MEDI_MUL'] 0.0
# ['WEIGHTED_STATUS_FIRST_YEAR_REST_MEAN_OVERALL'] 0.0
# ['DAYS_CREDIT_MEAN_OVERALL'] 0.0
# ['DAYS_FIRST_DUE_MEAN_FIRST_2'] 0.0
# ['EXP_MIN_PAYMENT_TOTAL_RATIO_LAST_ACTIVE'] 0.0
# ['INSTALLMENTS_ANNUITY_AMT_INSTALMENT_SUM_MAX_RATIO'] 0.0
# ['CNT_INSTALMENT_MEAN_YEAR_1_MAX'] 0.0
# ['AMT_GOODS_PRICE_MEAN_ALL'] 0.0
# ['DAYS_CREDIT_LASTCREDIT_ACTIVE_REST'] 0.0
# ['CNT_INSTALMENT_MEAN_YEAR_0_SUM'] 0.0
# ['EXP_PAYMENT_MIN_DIFF_LAST_COMPLETED'] 0.0
# ['BALANCE_LIMIT_RATIO_MIN_ACTIVE'] 0.0
# ['AMT_INCOME_TOTAL_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_SUM'] 0.0
# ['CNT_DRAWINGS_CURRENT_MAX'] 0.0
# ['PER_CAPITA_INCOME'] 0.0
# ['EXT_SOURCE_VAR'] 0.0
# ['PREV_AMT_ANNUITY_MEAN_FIRST_2_INCOME_RATIO'] 0.0
# ['WEIGHTED_EXT_SOURCE'] 0.0
# ['WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5'] 0.0
# ['NAME_EDUCATION_TYPE_0'] 0.0
# ['NAME_HOUSING_TYPE_0'] 0.0
# ['MIN_PAYMENT_TOTAL_RATIO_MEAN_ACTIVE'] 0.0
# ['DAYS_TERMINATION_MEAN_ALL'] 0.0
# ['DAYS_PAYMENT_DIFF_MEAN_MEAN'] 0.0
# ['SK_DPD_DEF_SUM_ACTIVE_MEAN'] 0.0
# ['CHANNEL_TYPE_MEAN_LAST_5'] 0.0
# ['FONDKAPREMONT_MODE_0'] 0.0
# ['DEF_30_CNT_SOCIAL_CIRCLE'] 0.0
# ['NAME_YIELD_GROUP_MEAN_LAST_5'] 0.0
# ['SK_DPD_DEF_MAX_YEAR_0_MEAN'] 0.0
# ['YEARS_BEGINEXPLUATATION_MEDI'] 0.0
# ['TOTAL_TERM_MEAN_ACTIVE_SUM'] 0.0
# ['CODE_REJECT_REASON_MEAN_ALL'] 0.0
# ['AMT_CREDIT_YIELD_GROUP_SUM_LAST_5'] 0.0
# ['BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF'] 0.0
# ['AMT_DECLINED_MEAN_LAST_5'] 0.0
# ['TOTAL_TERM_MEAN_ACTIVE_MEAN'] 0.0
# ['AMT_ANNUITY_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['AMT_INTEREST_SUM_LAST_5'] 0.0
# ['WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2'] 0.0
# ['EXT_SOURCE_3_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['SK_DPD_DEF_SUM_YEAR_0_MEAN'] 0.0
# ['CNT_DRAWING_SUM_SUM_ACTIVE'] 0.0
# ['ANNUITY_MAX_LAST_5'] 0.0
# ['FLAG_DOCUMENT_16'] 0.0
# ['ANNUITY_MAX_ALL'] 0.0
# ['EXT_SOURCE_1_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['AMT_APPLICATION_SUM_FIRST_2'] 0.0
# ['TOTAL_TERM_MAX_YEAR_0_MEAN'] 0.0
# ['FLOORSMIN_MEDI'] 0.0
# ['STATUS_MEAN_YEAR_0_MEAN_OVERALL'] 0.0
# ['AMT_PAYMENT_MAX_FIRST_5_INSTALLMENTS'] 0.0
# ['APARTMENTS_SUM_AVG_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['CREDIT_TYPE_Interbank credit_MEAN_OVERALL'] 0.0
# ['PREV_AMT_GOODS_PRICE_MAX_ALL_INCOME_RATIO'] 0.0
# ['AMT_PAYMENT_CURRENT_MIN'] 0.0
# ['WEIGHTED_STATUS_MAX_YEAR_0_MEAN_OVERALL'] 0.0
# ['AMT_ANNUITY_CREDIT_RATIO_MAX_CREDITACTIVE_ACTIVE'] 0.0
# ['AMT_GOODS_PRICE_MAX_FIRST_2'] 0.0
# ['AMT_PAYMENT_RATIO_MEAN_MIN'] 0.0
# ['CNT_INSTALMENT_FUTURE_MIN_YEAR_0_MEAN'] 0.0
# ['BUREAU_DAYS_CREDIT_LAST_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF'] 0.0
# ['EXP_MIN_PAYMENT_RATIO_LAST_COMPLETED'] 0.0
# ['DAYS_FIRST_DRAWING_MEAN_FIRST_2'] 0.0
# ['NAME_TYPE_SUITE_MEAN_ALL'] 0.0
# ['BUREAU_AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL_INCOME_RATIO'] 0.0
# ['HOUR_APPR_PROCESS_START'] 0.0
# ['EXT_SOURCE_3_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['INTEREST_SHARE_MIN_FIRST_2'] 0.0
# ['ANNUITY_INCOME_RATIO_MIN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['OBS_60_CREDIT_RATIO'] 0.0
# ['INTEREST_SHARE_MIN_LAST_5'] 0.0
# ['EXPECTED_INTEREST_RATE'] 0.0
# ['STATUS_FIRST_MEAN_OVERALL'] 0.0
# ['ANNUITY_SUM_ALL'] 0.0
# ['APARTMENTS_SUM_MEDI_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['AMT_PAYMENT_RATIO_MIN_MEAN'] 0.0
# ['AMT_INSTALMENT_MEAN_MAX'] 0.0
# ['BUREAU_DAYS_CREDIT_MEANCREDIT_ACTIVE_REST_REGISTRATION_DIFF'] 0.0
# ['INTEREST_RATE_MIN_FIRST_2'] 0.0
# ['AMT_PAYMENT_DIFF_MEAN_MIN'] 0.0
# ['AMT_CREDIT_SUM_MAX_CREDITACTIVE_ACTIVE'] 0.0
# ['AMT_INCOME_TOTAL_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['EXT_SOURCE_2_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['NONLIVINGAPARTMENTS_AVG'] 0.0
# ['AMT_CREDIT_MAX_OVERDUE_SUMCREDIT_ACTIVE_REST'] 0.0
# ['AMT_PAYMENT_SUM_MAX'] 0.0
# ['FLOORSMAX_MODE'] 0.0
# ['BUREAU_DAYS_CREDIT_MIN_CREDITACTIVE_ACTIVE_EMPLOYED_DIFF'] 0.0
# ['ORGANIZATION_TYPE_1'] 0.0
# ['NAME_CONTRACT_TYPE_MEAN_LAST_5'] 0.0
# ['CREDIT_DOWNPAYMENT_RATIO_MEAN_ALL'] 0.0
# ['AGE_EMPLOYED_DIFF_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['NAME_CASH_LOAN_PURPOSE_MEAN_ALL'] 0.0
# ['AMT_CREDIT_GOODS_RATIO_MEAN_ALL'] 0.0
# ['WEIGHTED_STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE'] 0.0
# ['ANNUITY_GOODS_SUM_LAST_5'] 0.0
# ['EXT_SOURCE_MEAN_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['NAME_CASH_LOAN_PURPOSE_LAST_FIRST_2'] 0.0
# ['EXP_CNT_INSTALMENT_FUTURE_LAST_YEAR_REST_MEAN'] 0.0
# ['DAYS_FIRST_LAST_DUE_DIFF_MAX_LAST_5'] 0.0
# ['AMT_INTEREST_SUM_FIRST_2'] 0.0
# ['AMT_TOTAL_RECEIVABLE_MAX'] 0.0
# ['EXT_SOURCE_3_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['AMT_INST_MIN_REGULARITY_MEAN'] 0.0
# ['DAYS_LAST_DUE_1ST_VERSION_MEAN_LAST_5'] 0.0
# ['CREDIT_TYPE_Car loan_MEAN_OVERALL'] 0.0
# ['AMT_INTEREST_MEAN_ALL'] 0.0
# ['DAYS_FIRST_DUE_MAX_LAST_5'] 0.0
# ['APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5'] 0.0
# ['TOTAL_TERM_MEAN_YEAR_REST_MAX'] 0.0
# ['NUM_INSTALMENT_NUMBER_MAX_MAX'] 0.0
# ['APARTMENTS_SUM_AVG_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['DAYS_FIRST_DRAWING_MEAN_ALL'] 0.0
# ['INSTALLMENTS_AMT_PAYMENT_MEAN_SUM_INCOME_RATIO'] 0.0
# ['ANNUITY_INCOME_RATIO_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['NONLIVINGAREA_MEDI'] 0.0
# ['NUM_INSTALMENT_VERSION_SUM_LAST_1_YEAR'] 0.0
# ['AMT_PAYMENT_DIFF_MIN_FIRST_5_INSTALLMENTS'] 0.0
# ['WALLSMATERIAL_MODE_0'] 0.0
# ['EXT_SOURCE_MUL'] 0.0
# ['AMT_INCOME_TOTAL_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['CC_AMT_RECIVABLE_SUM_INCOME_RATIO'] 0.0
# ['MAX_AMT_OVERDUE_DURATION_RATIO_MEAN_OVERALL'] 0.0
# ['APARTMENTS_SUM_AVG_MAX_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY'] 0.0
# ['CNT_INSTALMENT_FUTURE_MEAN_ACTIVE_MAX'] 0.0
# ['EXP_MIN_PAYMENT_TOTAL_RATIO_LAST_YEAR_REST'] 0.0
# ['AMT_CREDIT'] 0.0
# ['AMT_CREDIT_GOODS_DIFF_MEAN_LAST_5'] 0.0
# ['CNT_INSTALMENT_FUTURE_MEAN_YEAR_1_MEAN'] 0.0
# ['APARTMENTS_SUM_MEDI_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['EXT_SOURCE_1_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['EXT_SOURCE_1_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['AMT_ANNUITY_CREDIT_RATIO_MEAN_OVERALL'] 0.0
# ['AMT_CREDIT_GOODS_DIFF_MEAN_FIRST_2'] 0.0
# ['DAYS_PAYMENT_DIFF_MAX_MAX'] 0.0
# ['EXT_SOURCE_2_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['EXP_ENCODED_STATUS_LAST_MEAN_OVERALL'] 0.0
# ['AMT_PAYMENT_SUM_MEAN'] 0.0
# ['EXP_AMT_DRAWING_SUM_LAST'] 0.0
# ['EXT_SOURCE_1_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['NAME_CLIENT_TYPE_MEAN_ALL'] 0.0
# ['PREV_AMT_ANNUITY_SUM_LAST_5_INCOME_RATIO'] 0.0
# ['NUM_INSTALMENT_VERSION_MEAN_FIRST_5_INSTALLMENTS'] 0.0
# ['AMT_BALANCE_MEAN'] 0.0
# ['AMT_OVERDUE_DURATION_LEFT_RATIO_MEAN_OVERALL'] 0.0
# ['AMT_CREDIT_YIELD_GROUP_MIN_ALL'] 0.0
# ['AMT_DECLINED_MAX_LAST_5'] 0.0
# ['NAME_GOODS_CATEGORY_MEAN_LAST_5'] 0.0
# ['AMT_CREDIT_YIELD_GROUP_SUM_FIRST_2'] 0.0
# ['AMT_INTEREST_MAX_LAST_5'] 0.0
# ['TOTAL_TERM_MEAN_MEAN'] 0.0
# ['ANNUITY_INCOME_RATIO'] 0.0
# ['AMT_DRAWING_SUM_MAX'] 0.0
# ['GOOD_DOWNPAYMET_RATIO_MEAN_ALL'] 0.0
# ['EXT_SOURCE_2_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['WEIGHTED_STATUS_MEAN_MAX_CREDITACTIVE_CLOSED'] 0.0
# ['EXP_CNT_DRAWING_SUM_LAST_YEAR_REST'] 0.0
# ['DAYS_PAYMENT_RATIO_MIN_MEAN'] 0.0
# ['CURRENCY_currency 2_MEAN_OVERALL'] 0.0
# ['AMT_DOWN_PAYMENT_MAX_LAST_5'] 0.0
# ['CREDIT_TYPE_Microloan_MEAN_OVERALL'] 0.0
# ['BUREAU_AMT_CREDIT_SUM_OVERDUE_SUM_CREDITACTIVE_ACTIVE_INCOME_RATIO'] 0.0
# ['EXP_AMT_RECIVABLE_LAST'] 0.0
# ['NAME_SELLER_INDUSTRY_MEAN_FIRST_2'] 0.0
# ['FLAG_PHONE'] 0.0
# ['AGE_EMPLOYED_DIFF_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['EXT_SOURCE_MEAN_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE'] 0.0
# ['AMT_ANNUITY_MAX_FIRST_2'] 0.0
# ['EXT_SOURCE_MEAN_MAX_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE'] 0.0
# ['INSTALLMENTS_AMT_PAYMENT_SUM_MEAN_INCOME_RATIO'] 0.0
# ['AMT_INCOME_TOTAL_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE'] 0.0
# ['AMT_CREDIT_HOUR_PROCESS_START_SUM_FIRST_2'] 0.0
# ['AMT_RECIVABLE_MEAN'] 0.0
# ['AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL'] 0.0
# ['AMT_PAYMENT_DIFF_MAX_MAX'] 0.0
# ['BASEMENTAREA_AVG'] 0.0
# ['INSTALLMENTS_AMT_PAYMENT_MEAN_LAST_1_YEAR_INCOME_RATIO'] 0.0
# ['DAYS_PAYMENT_DIFF_MAX_FIRST_5_INSTALLMENTS'] 0.0
# ['AMT_INTEREST_RECEIVABLE_MEAN_YEAR_1'] 0.0
# ['STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE'] 0.0
# ['MIN_PAYMENT_TOTAL_RATIO_MEAN_YEAR_0'] 0.0
# ['AMT_PAYMENT_TOTAL_CURRENT_MAX'] 0.0
# ['SK_DPD_RATIO_MEAN_YEAR_1_MEAN'] 0.0
# ['REGION_RATING_MUL_0'] 0.0
# ['AMT_ANNUITY_MEAN_CREDITACTIVE_CLOSED'] 0.0
# ['INTEREST_RATE_MAX_ALL'] 0.0
# ['NUM_INSTALMENT_VERSION_MEAN_MEAN'] 0.0
# ['EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_1'] 0.0
# ['RATE_DOWN_PAYMENT_MAX_LAST_5'] 0.0
# ['BALANCE_LIMIT_RATIO_MEAN'] 0.0
# ['NAME_SELLER_INDUSTRY_LAST_FIRST_2'] 0.0
# ['APARTMENTS_SUM_AVG_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE'] 0.0
# ['AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2'] 0.0
# ['LIVINGAPARTMENTS_AVG'] 0.0
# ['CNT_PAYMENT_SUM_ALL'] 0.0
# ['ENTRANCES_AVG'] 0.0
# ['BUREAU_DAYS_CREDIT_MIN_CREDITACTIVE_CLOSED_EMPLOYED_DIFF'] 0.0
# ['AMT_PAYMENT_DIFF_MEAN_MEAN'] 0.0
# ['FLAG_DOCUMENT_3'] 0.0
# ['GOOD_DOWNPAYMET_RATIO_MEAN_FIRST_2'] 0.0
# ['AMT_DECLINED_SUM_FIRST_2'] 0.0
# ['INTEREST_RATE_MEAN_FIRST_2'] 0.0
# ['TOTAL_TERM_MEAN_YEAR_1_MAX'] 0.0
# ['NUM_INSTALMENT_VERSION_MEAN_LAST_1_YEAR'] 0.0
# ['EXP_CNT_DRAWING_SUM_LAST_YEAR_1'] 0.0

# %%
plot_importance(model, max_num_features = 20)
plt.show()

# %%
# create a train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)
d_train = xgboost.DMatrix(X_train, label=y_train)
d_test = xgboost.DMatrix(X_test, label=y_test)

# %% [markdown]
# **Formation du modèle**

# %%
params = {
    "eta": 0.01,
    "objective": "binary:logistic",
    "subsample": 0.5,
    "base_score": np.mean(y_train),
    "eval_metric": "logloss"
}
model = xgboost.train(params, d_train, 10000, evals = [(d_test, "test")], verbose_eval=100, early_stopping_rounds=20)
# Out:
# [0]	test-logloss:0.28572
# [100]	test-logloss:0.26075
# [200]	test-logloss:0.25517
# [265]	test-logloss:0.25427

# %% [markdown]
# **Explication des prédictions**

# %%
# this takes a minute or two since we are explaining over 30 thousand samples in a model with over a thousand trees
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# %% [markdown]
# **Visualisez une seule prédiction**

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div id='i9HOXRKFZXYRYI0NLQFZU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.4414474964141846, "outValue": -3.6708521842956543, "link": "identity", "featureNames": ["SK_ID_CURR", "AMT_PAYMENT_RATIO_MAX_LAST_1_YEAR", "EXP_AMT_PAYMENT_RATIO_LAST_MEAN", "AMT_DECLINED_SUM_FIRST_2", "CNT_INSTALMENT_MEAN_REST_MAX", "HOUSETYPE_MODE_0", "MISSING_VALS_TOTAL_INSTAL_SUM_SUM", "CONTRACT_APPROVED_MEAN", "EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_1", "APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL", "SK_DPD_RATIO_MEAN_YEAR_1_MEAN", "TOTAL_TERM_MEAN_YEAR_1_SUM", "AMT_BALANCE_MEAN", "TOTAL_TERM_MEAN_MAX", "EXP_ENCODED_STATUS_LAST_YEAR_1_MEAN_OVERALL", "CNT_INSTALMENT_MEAN_REST_SUM", "EXT_SOURCE_MEAN_MEAN_AGG_NAME_CONTRACT_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE", "YEARS_BEGINEXPLUATATION_MEDI", "DAYS_FIRST_DUE_MEAN_ALL", "CREDIT_ANNUITY_RATIO", "AMT_REQ_CREDIT_BUREAU_WEEK", "TOTAL_TERM_MEAN_REST_MEAN", "DAYS_FIRST_DUE_MAX_LAST_5", "AMT_CREDIT_GOODS_DIFF_SUM_LAST_5", "DAYS_TERMINATION_MAX_LAST_5", "DAYS_DETAILS_CHANGE_MUL", "AMT_CREDIT_MAX_OVERDUE_SUM_CREDITACTIVE_CLOSED", "AGE_EMPLOYED_DIFF_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY", "RATE_DOWN_PAYMENT_MEAN_LAST_5", "FLAG_DOCUMENT_14", "AMT_DRAWINGS_ATM_CURRENT_MAX", "APARTMENTS_SUM_MEDI_MIN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY", "SK_DPD_RATIO_MEAN_YEAR_0_MAX", "SELLERPLACE_AREA_MEAN_LAST_5", "CREDIT_ACTIVE_Bad debt_MEAN_OVERALL", "OCCUPATION_TYPE_0", "CNT_INSTALMENT_FUTURE_MEAN_YEAR_0_MEAN", "DAYS_FIRST_DUE_MEAN_LAST_5", "WEIGHTED_STATUS_FIRST_YEAR_REST_MEAN_OVERALL", "CREDIT_DOWNPAYMENT_RATIO_MAX_FIRST_2", "BUREAU_DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED_REGISTRATION_DIFF", "AMT_ANNUITY_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE", "EXT_SOURCE_2_MAX_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE", "SELLERPLACE_AREA_MIN_LAST_5", "SK_DPD_RATIO_MEAN", "CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL", "DAYS_PAYMENT_RATIO_MEAN_MIN", "NAME_CLIENT_TYPE_MEAN_LAST_5", "CHANNEL_TYPE_MEAN_FIRST_2", "MONTHS_BALANCE_MAX", "BALANCE_LIMIT_RATIO_MIN", "EXT_SOURCE_3_MIN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE", "EXP_POS_TOTAL_TERM_MEAN_MAX", "NUM_INSTALMENT_NUMBER_MAX_MAX", "ANNUITY_SUM_ALL", "FLAG_PHONE", "DAYS_DECISION_MAX_LAST_5", "WEIGHTED_STATUS_MEAN_YEAR_REST_MEAN_OVERALL", "EXT_SOURCE_1_MEAN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE", "ANNUITY_INCOME_RATIO_MIN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE", "STATUS_MAX_YEAR_1_MEAN_OVERALL", "PRODUCT_COMBINATION_LAST_LAST_5", "NAME_GOODS_CATEGORY_LAST_FIRST_2", "EXT_SOURCE_3_MAX_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE", "GOOD_DOWNPAYMET_RATIO_MEAN_LAST_5", "AMT_ENQ_SUM", "DAYS_PAYMENT_DIFF_MEAN_LAST_1_YEAR", "CREDIT_DAY_OVERDUE_MAX_CREDITACTIVE_ACTIVE", "YEARS_BEGINEXPLUATATION_MODE", "AMT_CREDIT_GOODS_RATIO_MEAN_ALL", "DAYS_PAYMENT_DIFF_MAX_LAST_1_YEAR", "DAYS_FIRST_DUE_MAX_ALL", "AMT_INSTALMENT_SUM_FIRST_5_INSTALLMENTS", "INTEREST_SHARE_MAX_FIRST_2", "CNT_PAYMENT_MEAN_FIRST_2", "AMT_INTEREST_SUM_FIRST_2", "INTEREST_SHARE_MEAN_ALL", "DAYS_PAYMENT_RATIO_MAX_MEAN", "ANNUITY_MEAN_FIRST_2", "EXP_BALANCE_LIMIT_RATIO_LAST_ACTIVE", "NAME_TYPE_SUITE_MEAN_LAST_5", "EXT_SOURCE_1_MEAN_AGG_FLAG_OWN_CAR_FLAG_OWN_REALTY_NAME_INCOME_TYPE", "AMT_ANNUITY_CREDIT_RATIO_MIN_CREDITACTIVE_CLOSED", "NAME_GOODS_CATEGORY_LAST_LAST_5", "DAYS_CREDIT_MEAN_CREDITACTIVE_CLOSED", "APARTMENTS_MODE", "AMT_ANNUITY", "EXP_MIN_PAYMENT_RATIO_LAST_YEAR_REST", "EXP_AMT_PAYMENT_DIFF_LAST_FIRST_5_INSTALLMENTS", "STATUS_MEAN_MAX_CREDITACTIVE_ACTIVE", "AMT_INTEREST_RECEIVABLE_MEAN_YEAR_REST", "APARTMENTS_MEDI", "WEIGHTED_STATUS_LAST_YEAR_1_MEAN_OVERALL", "PAYMENT_MIN_DIFF_MEAN", "AMT_PAYMENT_MEAN_SUM", "EXP_POS_TOTAL_TERM_LAST_YEAR_1_MEAN", "EXT_SOURCE_1_MEAN_AGG_NAME_EDUCATION_TYPE_NAME_INCOME_TYPE_OCCUPATION_TYPE", "EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_REST", "AMT_CREDIT_MAX_ALL", "APARTMENTS_SUM_AVG_MIN_AGG_OCCUPATION_TYPE_ORGANIZATION_TYPE", "APARTMENTS_SUM_AVG_MAX_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE", "AMT_APPLICATION_ ...

# %% [markdown]
# **Diagramme à barres d'importance moyenne**

# %%
test_shape.head(2)
# Out:
#    SK_ID_CURR  AMT_PAYMENT_RATIO_MAX_LAST_1_YEAR  \
# 0      100001                                0.0
# 1      100005                                0.0
#
#    EXP_AMT_PAYMENT_RATIO_LAST_MEAN  AMT_DECLINED_SUM_FIRST_2  \
# 0                        -0.004855                  0.275682
# 1                        -0.004855                  0.323084
#
#    CNT_INSTALMENT_MEAN_REST_MAX  HOUSETYPE_MODE_0  \
# 0                           0.0          0.985322
# 1                           0.0         -1.003499
#
#    MISSING_VALS_TOTAL_INSTAL_SUM_SUM  CONTRACT_APPROVED_MEAN  \
# 0                          -0.044103               -0.076727
# 1                          -0.044103               -0.076727
#
#    EXP_BALANCE_LIMIT_RATIO_LAST_YEAR_1  \
# 0                                  0.0
# 1                                  0.0
#
#    APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL  ...  \
# 0                                   -0.127721  ...
# 1                                   -0.124166  ...
#
#    AMT_INCOME_TOTAL_MEAN_AGG_CODE_GENDER_FLAG_OWN_CAR_FLAG_OWN_REALTY  \
# 0                                          -0.783238
# 1                                           0.253911
#
#    APARTMENTS_SUM_AVG_MEAN_AGG_CODE_GENDER_NAME_FAMILY_STATUS_NAME_INCOME_TYPE  \
# 0                                          -0.755249
# 1                                          -0.301066
#
#    SELLERPLACE_AREA_MIN_FIRST_2  ANNUITY_SUM_FIRST_2  AMT_DECLINED_SUM_ALL  \
# 0                     -0.102941            -0.249206              0.458227
# 1                     -0.113035            -0.249206              0.472952
#
#    CNT_INSTALMENT_MAX_YEAR_1_MEAN  AMT_ANNUITY_MEAN_CREDITACTIVE_CLOSED  \
# 0                        0.000000                             -0.059158
# 1                       -0.549125                             -0.059158
#
#    DAYS_FIRST_LAST_DUE_DIFF_MEAN_ALL  STATUS_MEAN_MEAN_CREDITACTIVE_ACTIVE  \
# 0                          -1.089177                             -0.241684
# 1                          -0.138740                             -0.644074
#
#    ANNUITY_GOODS_MEAN_FIRST_2
# 0                   -0.170972
# 1                   -0.170972
#
# [2 rows x 1241 columns]

# %%
# shap.summary_plot(shap_values, X, plot_type="bar")
shap.summary_plot(shap_values, test_shape[test_shape['SK_ID_CURR'] == 100001], max_display=10, plot_type ="bar", color_bar=False)

# %% [markdown]
# ## [9. Préparation du Logo pour le dashboard](#plan)<a class="anchor" id="9"></a>

# %%
import os
import glob

from PIL import Image, ImageDraw, ImageFilter

im = Image.open('logo/logo_pad.png')
thumb_width = 200

# %%
def crop_center(pil_img, crop_width, crop_height):
    img_width, img_height = pil_img.size
    return pil_img.crop(((img_width - crop_width) // 2,
                         (img_height - crop_height) // 2,
                         (img_width + crop_width) // 2,
                         (img_height + crop_height) // 2))

# %%
def crop_max_square(pil_img):
    return crop_center(pil_img, min(pil_img.size), min(pil_img.size))

# %%
def mask_circle_transparent(pil_img, blur_radius, offset=0):
    offset = blur_radius * 2 + offset
    mask = Image.new("L", pil_img.size, 0)
    draw = ImageDraw.Draw(mask)
    draw.ellipse((offset, offset, pil_img.size[0] - offset, pil_img.size[1] - offset), fill=255)
    mask = mask.filter(ImageFilter.GaussianBlur(blur_radius))

    result = pil_img.copy()
    result.putalpha(mask)

    return result

# %%
im_square = crop_max_square(im).resize((thumb_width, thumb_width), Image.LANCZOS)
im_thumb = mask_circle_transparent(im_square, 4)
# im_thumb.save('data/dst/astronaut_thumbnail_mask_circle_transparent.png')
im_thumb
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x2965F48ACD0>
